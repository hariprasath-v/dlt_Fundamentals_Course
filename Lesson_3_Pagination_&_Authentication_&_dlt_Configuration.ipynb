# %% [markdown]
# # **Recap of [Lesson 2](https://colab.research.google.com/drive/1tc94GvIoYXmYrjUibDhY_9iPR5zA0Eyw?usp=sharing) 👩‍💻🚀**
#
# 1.  Used `@dlt.resource` to load and query data like lists, dataframes, and REST API responses into DuckDB.
# 2.  Grouped multiple resources into a single `@dlt.source` for better organization and efficiency.
# 3.  Used `@dlt.transformer` to process and enrich data between resources.
#
# Next: Dive deeper into building dlt pipelines using pagination, authentication and dlt configuration! 🚀

# %% [markdown]
# ---
#
# # **Pagination & Authentication & dlt Configuration** 🤫🔩
#
# **Here, you will learn how to:**
# - Use pagination for RestAPIs.
# - Use environment variables to handle both secrets & configs.
# - Add values to `secrets.toml` or `config.toml`.
#
# To read more about credentails refer to [dlt documentation](https://dlthub.com/docs/general-usage/credentials/) here.

# %% [markdown]
# In previous lesson we loaded data from GitHub API  to DuckDB,

# %%
# %%capture
# !pip install dlt

# %%
import dlt
from dlt.sources.helpers import requests


# define dlt resources
@dlt.resource
def github_events():
    url = "https://api.github.com/orgs/dlt-hub/events"
    response = requests.get(url)
    yield response.json()


# define dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")

# run dlt pipeline
load_info = pipeline.run(github_events)
print(load_info)

# explore loaded data
pipeline.dataset(dataset_type="default").github_events.df()
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 1.83 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1743232813.728906 is LOADED and contains no failed jobs
#              id                           type  actor__id  \
# 0   48083020508                     WatchEvent       9391
# 1   48077813800                     WatchEvent    1954680
# 2   48074908511                     WatchEvent   46582011
# 3   48073147341                    IssuesEvent   42041832
# 4   48070314242                     WatchEvent   40360560
# 5   48068133448         PullRequestReviewEvent   32450038
# 6   48068133014                      PushEvent    9139429
# 7   48068020043         PullRequestReviewEvent   32450038
# 8   48066407452                    IssuesEvent  205276272
# 9   48053997526                     WatchEvent  154931574
# 10  48052656076                      PushEvent   68975210
# 11  48051888327              IssueCommentEvent   29787333
# 12  48048829755                      PushEvent     264674
# 13  48048826530  PullRequestReviewCommentEvent     264674
# 14  48048826436         PullRequestReviewEvent     264674
# 15  48048750930                      PushEvent    9139429
# 16  48048659529                      PushEvent     264674
# 17  48048652417  PullRequestReviewCommentEvent     264674
# 18  48048652351         PullRequestReviewEvent     264674
# 19  48048645089         PullRequestReviewEvent     264674
# 20  48048645202  PullRequestReviewCommentEvent     264674
# 21  48048468966                      PushEvent     264674
# 22  48048465105         PullRequestReviewEvent     264674
# 23  48048465196  PullRequestReviewCommentEvent     264674
# 24  48048403982                      PushEvent     264674
# 25  48048385320  PullRequestReviewCommentEvent     264674
# 26  48048385230         PullRequestReviewEvent     264674
# 27  48048376905  PullRequestReviewCommentEvent     264674
# 28  48048376781         PullRequestReviewEvent     264674
# 29  48048143193                      PushEvent     264674
# 30  48083020508                     WatchEvent       9391
# 31  48077813800                     WatchEvent    1954680
# 32  48074908511                     WatchEvent   46582011
# 33  48073147341                    IssuesEvent   42041832
# 34  48070314242                     WatchEvent   40360560
# 35  48068133448         PullRequestReviewEvent   32450038
# 36  48068133014                      PushEvent    9139429
# 37  48068020043         PullRequestReviewEvent   32450038
# 38  48066407452                    IssuesEvent  205276272
# 39  48053997526                     WatchEvent  154931574
# 40  48052656076                      PushEvent   68975210
# 41  48051888327              IssueCommentEvent   29787333
# 42  48048829755                      PushEvent     264674
# 43  48048826530  PullRequestReviewCommentEvent     264674
# 44  48048826436         PullRequestReviewEvent     264674
# 45  48048750930                      PushEvent    9139429
# 46  48048659529                      PushEvent     264674
# 47  48048652417  PullRequestReviewCommentEvent     264674
# 48  48048652351         PullRequestReviewEvent     264674
# 49  48048645089         PullRequestReviewEvent     264674
# 50  48048645202  PullRequestReviewCommentEvent     264674
# 51  48048468966                      PushEvent     264674
# 52  48048465105         PullRequestReviewEvent     264674
# 53  48048465196  PullRequestReviewCommentEvent     264674
# 54  48048403982                      PushEvent     264674
# 55  48048385320  PullRequestReviewCommentEvent     264674
# 56  48048385230         PullRequestReviewEvent     264674
# 57  48048376905  PullRequestReviewCommentEvent     264674
# 58  48048376781         PullRequestReviewEvent     264674
# 59  48048143193                      PushEvent     264674
#
#                 actor__login      actor__display_login actor__gravatar_id  \
# 0                 benji-york                benji-york
# 1                   arstercz                  arstercz
# 2                   bhmilner                  bhmilner
# 3               abuchmueller              abuchmueller
# 4                    MHajjem                   MHajjem
# 5                     akelad                    akelad
# 6                    VioletM                   VioletM
# 7                     akelad                    akelad
# 8                  Smriti675                 Smriti675
# 9   leonardo-fernandes-atria  leonardo-fernandes-atria
# 10                     zilto                     zilto
# 11                  lgwacker                  lgwacker
# 12                   burnash                   burnash
# 13                   burnash                   burnash
# 14                   burnash                   burnash
# 15                   VioletM                   VioletM
# 16                   burnash                   burnash
# 17                   burnash                   burnash
# 18                   burnash                   burnash
# 19                   burnash                   burnash
# 20                   burnash                   burnash
# 21                   burnash                   burnash
# 22                   burnash                   burnash
# 23                   burnash                   burnash
# 24                   burnash                   burnash
# 25                   burnash                   burnash
# 26                   burnash                   burnash
# 27                   burnash                   burnash
# 28                   burnash                   burnash
# 29                   burnash                   burnash
# 30                benji-york                benji-york
# 31                  arstercz                  arstercz
# 32                  bhmilner                  bhmilner
# 33              abuchmueller              abuchmueller
# 34                   MHajjem                   MHajjem
# 35                    akelad                    akelad
# 36                   VioletM                   VioletM
# 37                    akelad                    akelad
# 38                 Smriti675                 Smriti675
# 39  leonardo-fernandes-atria  leonardo-fernandes-atria
# 40                     zilto                     zilto
# 41                  lgwacker                  lgwacker
# 42                   burnash                   burnash
# 43                   burnash                   burnash
# 44                   burnash                   burnash
# 45                   VioletM                   VioletM
# 46                   burnash                   burnash
# 47                   burnash                   burnash
# 48                   burnash                   burnash
# 49                   burnash                   burnash
# 50                   burnash                   burnash
# 51                   burnash                   burnash
# 52                   burnash                   burnash
# 53                   burnash                   burnash
# 54                   burnash                   burnash
# 55                   burnash                   burnash
# 56                   burnash                   burnash
# 57                   burnash                   burnash
# 58                   burnash                   burnash
# 59                   burnash                   burnash
#
#                                            actor__url  \
# 0             https://api.github.com/users/benji-york
# 1               https://api.github.com/users/arstercz
# 2               https://api.github.com/users/bhmilner
# 3           https://api.github.com/users/abuchmueller
# 4                https://api.github.com/users/MHajjem
# 5                 https://api.github.com/users/akelad
# 6                https://api.github.com/users/VioletM
# 7                 https://api.github.com/users/akelad
# 8              https://api.github.com/users/Smriti675
# 9   https://api.github.com/users/leonardo-fernande...
# 10                 https://api.github.com/users/zilto
# 11              https://api.github.com/users/lgwacker
# 12               https://api.github.com/users/burnash
# 13               https://api.github.com/users/burnash
# 14               https://api.github.com/users/burnash
# 15               https://api.github.com/users/VioletM
# 16               https://api.github.com/users/burnash
# 17               https://api.github.com/users/burnash
# 18               https://api.github.com/users/burnash
# 19               https://api.github.com/users/burnash
# 20               https://api.github.com/users/burnash
# 21               https://api.github.com/users/burnash
# 22               https://api.github.com/users/burnash
# 23               https://api.github.com/users/burnash
# 24               https://api.github.com/users/burnash
# 25               https://api.github.com/users/burnash
# 26               https://api.github.com/users/burnash
# 27               https://api.github.com/users/burnash
# 28               https://api.github.com/users/burnash
# 29               https://api.github.com/users/burnash
# 30            https://api.github.com/users/benji-york
# 31              https://api.github.com/users/arstercz
# 32              https://api.github.com/users/bhmilner
# 33          https://api.github.com/users/abuchmueller
# 34               https://api.github.com/users/MHajjem
# 35                https://api.github.com/users/akelad
# 36               https://api.github.com/users/VioletM
# 37                https://api.github.com/users/akelad
# 38             https://api.github.com/users/Smriti675
# 39  https://api.github.com/users/leonardo-fernande...
# 40                 https://api.github.com/users/zilto
# 41              https://api.github.com/users/lgwacker
# 42               https://api.github.com/users/burnash
# 43               https://api.github.com/users/burnash
# 44               https://api.github.com/users/burnash
# 45               https://api.github.com/users/VioletM
# 46               https://api.github.com/users/burnash
# 47               https://api.github.com/users/burnash
# 48               https://api.github.com/users/burnash
# 49               https://api.github.com/users/burnash
# 50               https://api.github.com/users/burnash
# 51               https://api.github.com/users/burnash
# 52               https://api.github.com/users/burnash
# 53               https://api.github.com/users/burnash
# 54               https://api.github.com/users/burnash
# 55               https://api.github.com/users/burnash
# 56               https://api.github.com/users/burnash
# 57               https://api.github.com/users/burnash
# 58               https://api.github.com/users/burnash
# 59               https://api.github.com/users/burnash
#
#                                     actor__avatar_url   repo__id  \
# 0       https://avatars.githubusercontent.com/u/9391?  452221115
# 1    https://avatars.githubusercontent.com/u/1954680?  452221115
# 2   https://avatars.githubusercontent.com/u/46582011?  791903865
# 3   https://avatars.githubusercontent.com/u/42041832?  452221115
# 4   https://avatars.githubusercontent.com/u/40360560?  452221115
# 5   https://avatars.githubusercontent.com/u/32450038?  452221115
# 6    https://avatars.githubusercontent.com/u/9139429?  452221115
# 7   https://avatars.githubusercontent.com/u/32450038?  452221115
# 8   https://avatars.githubusercontent.com/u/205276...  452221115
# 9   https://avatars.githubusercontent.com/u/154931...  452221115
# 10  https://avatars.githubusercontent.com/u/68975210?  452221115
# 11  https://avatars.githubusercontent.com/u/29787333?  584776311
# 12    https://avatars.githubusercontent.com/u/264674?  452221115
# 13    https://avatars.githubusercontent.com/u/264674?  452221115
# 14    https://avatars.githubusercontent.com/u/264674?  452221115
# 15   https://avatars.githubusercontent.com/u/9139429?  452221115
# 16    https://avatars.githubusercontent.com/u/264674?  452221115
# 17    https://avatars.githubusercontent.com/u/264674?  452221115
# 18    https://avatars.githubusercontent.com/u/264674?  452221115
# 19    https://avatars.githubusercontent.com/u/264674?  452221115
# 20    https://avatars.githubusercontent.com/u/264674?  452221115
# 21    https://avatars.githubusercontent.com/u/264674?  452221115
# 22    https://avatars.githubusercontent.com/u/264674?  452221115
# 23    https://avatars.githubusercontent.com/u/264674?  452221115
# 24    https://avatars.githubusercontent.com/u/264674?  452221115
# 25    https://avatars.githubusercontent.com/u/264674?  452221115
# 26    https://avatars.githubusercontent.com/u/264674?  452221115
# 27    https://avatars.githubusercontent.com/u/264674?  452221115
# 28    https://avatars.githubusercontent.com/u/264674?  452221115
# 29    https://avatars.githubusercontent.com/u/264674?  452221115
# 30      https://avatars.githubusercontent.com/u/9391?  452221115
# 31   https://avatars.githubusercontent.com/u/1954680?  452221115
# 32  https://avatars.githubusercontent.com/u/46582011?  791903865
# 33  https://avatars.githubusercontent.com/u/42041832?  452221115
# 34  https://avatars.githubusercontent.com/u/40360560?  452221115
# 35  https://avatars.githubusercontent.com/u/32450038?  452221115
# 36   https://avatars.githubusercontent.com/u/9139429?  452221115
# 37  https://avatars.githubusercontent.com/u/32450038?  452221115
# 38  https://avatars.githubusercontent.com/u/205276...  452221115
# 39  https://avatars.githubusercontent.com/u/154931...  452221115
# 40  https://avatars.githubusercontent.com/u/68975210?  452221115
# 41  https://avatars.githubusercontent.com/u/29787333?  584776311
# 42    https://avatars.githubusercontent.com/u/264674?  452221115
# 43    https://avatars.githubusercontent.com/u/264674?  452221115
# 44    https://avatars.githubusercontent.com/u/264674?  452221115
# 45   https://avatars.githubusercontent.com/u/9139429?  452221115
# 46    https://avatars.githubusercontent.com/u/264674?  452221115
# 47    https://avatars.githubusercontent.com/u/264674?  452221115
# 48    https://avatars.githubusercontent.com/u/264674?  452221115
# 49    https://avatars.githubusercontent.com/u/264674?  452221115
# 50    https://avatars.githubusercontent.com/u/264674?  452221115
# 51    https://avatars.githubusercontent.com/u/264674?  452221115
# 52    https://avatars.githubusercontent.com/u/264674?  452221115
# 53    https://avatars.githubusercontent.com/u/264674?  452221115
# 54    https://avatars.githubusercontent.com/u/264674?  452221115
# 55    https://avatars.githubusercontent.com/u/264674?  452221115
# 56    https://avatars.githubusercontent.com/u/264674?  452221115
# 57    https://avatars.githubusercontent.com/u/264674?  452221115
# 58    https://avatars.githubusercontent.com/u/264674?  452221115
# 59    https://avatars.githubusercontent.com/u/264674?  452221115
#
#                   repo__name  ...  \
# 0                dlt-hub/dlt  ...
# 1                dlt-hub/dlt  ...
# 2   dlt-hub/dlt-init-openapi  ...
# 3                dlt-hub/dlt  ...
# 4                dlt-hub/dlt  ...
# 5                dlt-hub/dlt  ...
# 6                dlt-hub/dlt  ...
# 7                dlt-hub/dlt  ...
# 8                dlt-hub/dlt  ...
# 9                dlt-hub/dlt  ...
# 10               dlt-hub/dlt  ...
# 11  dlt-hub/verified-sources  ...
# 12               dlt-hub/dlt  ...
# 13               dlt-hub/dlt  ...
# 14               dlt-hub/dlt  ...
# 15               dlt-hub/dlt  ...
# 16               dlt-hub/dlt  ...
# 17               dlt-hub/dlt  ...
# 18               dlt-hub/dlt  ...
# 19               dlt-hub/dlt  ...
# 20               dlt-hub/dlt  ...
# 21               dlt-hub/dlt  ...
# 22               dlt-hub/dlt  ...
# 23               dlt-hub/dlt  ...
# 24               dlt-hub/dlt  ...
# 25               dlt-hub/dlt  ...
# 26               dlt-hub/dlt  ...
# 27               dlt-hub/dlt  ...
# 28               dlt-hub/dlt  ...
# 29               dlt-hub/dlt  ...
# 30               dlt-hub/dlt  ...
# 31               dlt-hub/dlt  ...
# 32  dlt-hub/dlt-init-openapi  ...
# 33               dlt-hub/dlt  ...
# 34               dlt-hub/dlt  ...
# 35               dlt-hub/dlt  ...
# 36               dlt-hub/dlt  ...
# 37               dlt-hub/dlt  ...
# 38               dlt-hub/dlt  ...
# 39               dlt-hub/dlt  ...
# 40               dlt-hub/dlt  ...
# 41  dlt-hub/verified-sources  ...
# 42               dlt-hub/dlt  ...
# 43               dlt-hub/dlt  ...
# 44               dlt-hub/dlt  ...
# 45               dlt-hub/dlt  ...
# 46               dlt-hub/dlt  ...
# 47               dlt-hub/dlt  ...
# 48               dlt-hub/dlt  ...
# 49               dlt-hub/dlt  ...
# 50               dlt-hub/dlt  ...
# 51               dlt-hub/dlt  ...
# 52               dlt-hub/dlt  ...
# 53               dlt-hub/dlt  ...
# 54               dlt-hub/dlt  ...
# 55               dlt-hub/dlt  ...
# 56               dlt-hub/dlt  ...
# 57               dlt-hub/dlt  ...
# 58               dlt-hub/dlt  ...
# 59               dlt-hub/dlt  ...
#
#                    payload__comment__pull_request_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 21                                               None
# 22                                               None
# 23  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 24                                               None
# 25  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 26                                               None
# 27  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 44                                               None
# 45                                               None
# 46                                               None
# 47  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 48                                               None
# 49                                               None
# 50  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 51                                               None
# 52                                               None
# 53  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 54                                               None
# 55  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 56                                               None
# 57  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 58                                               None
# 59                                               None
#
#                  payload__comment___links__self__href  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 21                                               None
# 22                                               None
# 23  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 24                                               None
# 25  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 26                                               None
# 27  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 44                                               None
# 45                                               None
# 46                                               None
# 47  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 48                                               None
# 49                                               None
# 50  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 51                                               None
# 52                                               None
# 53  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 54                                               None
# 55  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 56                                               None
# 57  https://api.github.com/repos/dlt-hub/dlt/pulls...
# 58                                               None
# 59                                               None
#
#                  payload__comment___links__html__href  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 18                                               None
# 19                                               None
# 20  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 21                                               None
# 22                                               None
# 23  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 24                                               None
# 25  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 26                                               None
# 27  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 44                                               None
# 45                                               None
# 46                                               None
# 47  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 48                                               None
# 49                                               None
# 50  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 51                                               None
# 52                                               None
# 53  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 54                                               None
# 55  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 56                                               None
# 57  https://github.com/dlt-hub/dlt/pull/2450#discu...
# 58                                               None
# 59                                               None
#
#          payload__comment___links__pull_request__href  payload__comment__line  \
# 0                                                None                    <NA>
# 1                                                None                    <NA>
# 2                                                None                    <NA>
# 3                                                None                    <NA>
# 4                                                None                    <NA>
# 5                                                None                    <NA>
# 6                                                None                    <NA>
# 7                                                None                    <NA>
# 8                                                None                    <NA>
# 9                                                None                    <NA>
# 10                                               None                    <NA>
# 11                                               None                    <NA>
# 12                                               None                    <NA>
# 13  https://api.github.com/repos/dlt-hub/dlt/pulls...                       9
# 14                                               None                    <NA>
# 15                                               None                    <NA>
# 16                                               None                    <NA>
# 17  https://api.github.com/repos/dlt-hub/dlt/pulls...                      99
# 18                                               None                    <NA>
# 19                                               None                    <NA>
# 20  https://api.github.com/repos/dlt-hub/dlt/pulls...                      97
# 21                                               None                    <NA>
# 22                                               None                    <NA>
# 23  https://api.github.com/repos/dlt-hub/dlt/pulls...                     100
# 24                                               None                    <NA>
# 25  https://api.github.com/repos/dlt-hub/dlt/pulls...                      33
# 26                                               None                    <NA>
# 27  https://api.github.com/repos/dlt-hub/dlt/pulls...                      32
# 28                                               None                    <NA>
# 29                                               None                    <NA>
# 30                                               None                    <NA>
# 31                                               None                    <NA>
# 32                                               None                    <NA>
# 33                                               None                    <NA>
# 34                                               None                    <NA>
# 35                                               None                    <NA>
# 36                                               None                    <NA>
# 37                                               None                    <NA>
# 38                                               None                    <NA>
# 39                                               None                    <NA>
# 40                                               None                    <NA>
# 41                                               None                    <NA>
# 42                                               None                    <NA>
# 43  https://api.github.com/repos/dlt-hub/dlt/pulls...                       9
# 44                                               None                    <NA>
# 45                                               None                    <NA>
# 46                                               None                    <NA>
# 47  https://api.github.com/repos/dlt-hub/dlt/pulls...                      99
# 48                                               None                    <NA>
# 49                                               None                    <NA>
# 50  https://api.github.com/repos/dlt-hub/dlt/pulls...                      97
# 51                                               None                    <NA>
# 52                                               None                    <NA>
# 53  https://api.github.com/repos/dlt-hub/dlt/pulls...                     100
# 54                                               None                    <NA>
# 55  https://api.github.com/repos/dlt-hub/dlt/pulls...                      33
# 56                                               None                    <NA>
# 57  https://api.github.com/repos/dlt-hub/dlt/pulls...                      32
# 58                                               None                    <NA>
# 59                                               None                    <NA>
#
#    payload__comment__original_line payload__comment__side  \
# 0                             <NA>                   None
# 1                             <NA>                   None
# 2                             <NA>                   None
# 3                             <NA>                   None
# 4                             <NA>                   None
# 5                             <NA>                   None
# 6                             <NA>                   None
# 7                             <NA>                   None
# 8                             <NA>                   None
# 9                             <NA>                   None
# 10                            <NA>                   None
# 11                            <NA>                   None
# 12                            <NA>                   None
# 13                               9                  RIGHT
# 14                            <NA>                   None
# 15                            <NA>                   None
# 16                            <NA>                   None
# 17                              99                  RIGHT
# 18                            <NA>                   None
# 19                            <NA>                   None
# 20                              97                  RIGHT
# 21                            <NA>                   None
# 22                            <NA>                   None
# 23                             100                  RIGHT
# 24                            <NA>                   None
# 25                              33                  RIGHT
# 26                            <NA>                   None
# 27                              32                  RIGHT
# 28                            <NA>                   None
# 29                            <NA>                   None
# 30                            <NA>                   None
# 31                            <NA>                   None
# 32                            <NA>                   None
# 33                            <NA>                   None
# 34                            <NA>                   None
# 35                            <NA>                   None
# 36                            <NA>                   None
# 37                            <NA>                   None
# 38                            <NA>                   None
# 39                            <NA>                   None
# 40                            <NA>                   None
# 41                            <NA>                   None
# 42                            <NA>                   None
# 43                               9                  RIGHT
# 44                            <NA>                   None
# 45                            <NA>                   None
# 46                            <NA>                   None
# 47                              99                  RIGHT
# 48                            <NA>                   None
# 49                            <NA>                   None
# 50                              97                  RIGHT
# 51                            <NA>                   None
# 52                            <NA>                   None
# 53                             100                  RIGHT
# 54                            <NA>                   None
# 55                              33                  RIGHT
# 56                            <NA>                   None
# 57                              32                  RIGHT
# 58                            <NA>                   None
# 59                            <NA>                   None
#
#    payload__comment__original_position payload__comment__position  \
# 0                                 <NA>                       <NA>
# 1                                 <NA>                       <NA>
# 2                                 <NA>                       <NA>
# 3                                 <NA>                       <NA>
# 4                                 <NA>                       <NA>
# 5                                 <NA>                       <NA>
# 6                                 <NA>                       <NA>
# 7                                 <NA>                       <NA>
# 8                                 <NA>                       <NA>
# 9                                 <NA>                       <NA>
# 10                                <NA>                       <NA>
# 11                                <NA>                       <NA>
# 12                                <NA>                       <NA>
# 13                                   9                          9
# 14                                <NA>                       <NA>
# 15                                <NA>                       <NA>
# 16                                <NA>                       <NA>
# 17                                  99                         99
# 18                                <NA>                       <NA>
# 19                                <NA>                       <NA>
# 20                                  97                         97
# 21                                <NA>                       <NA>
# 22                                <NA>                       <NA>
# 23                                 100                        100
# 24                                <NA>                       <NA>
# 25                                  33                         33
# 26                                <NA>                       <NA>
# 27                                  32                         32
# 28                                <NA>                       <NA>
# 29                                <NA>                       <NA>
# 30                                <NA>                       <NA>
# 31                                <NA>                       <NA>
# 32                                <NA>                       <NA>
# 33                                <NA>                       <NA>
# 34                                <NA>                       <NA>
# 35                                <NA>                       <NA>
# 36                                <NA>                       <NA>
# 37                                <NA>                       <NA>
# 38                                <NA>                       <NA>
# 39                                <NA>                       <NA>
# 40                                <NA>                       <NA>
# 41                                <NA>                       <NA>
# 42                                <NA>                       <NA>
# 43                                   9                          9
# 44                                <NA>                       <NA>
# 45                                <NA>                       <NA>
# 46                                <NA>                       <NA>
# 47                                  99                         99
# 48                                <NA>                       <NA>
# 49                                <NA>                       <NA>
# 50                                  97                         97
# 51                                <NA>                       <NA>
# 52                                <NA>                       <NA>
# 53                                 100                        100
# 54                                <NA>                       <NA>
# 55                                  33                         33
# 56                                <NA>                       <NA>
# 57                                  32                         32
# 58                                <NA>                       <NA>
# 59                                <NA>                       <NA>
#
#    payload__comment__subject_type
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# 5                            None
# 6                            None
# 7                            None
# 8                            None
# 9                            None
# 10                           None
# 11                           None
# 12                           None
# 13                           line
# 14                           None
# 15                           None
# 16                           None
# 17                           line
# 18                           None
# 19                           None
# 20                           line
# 21                           None
# 22                           None
# 23                           line
# 24                           None
# 25                           line
# 26                           None
# 27                           line
# 28                           None
# 29                           None
# 30                           None
# 31                           None
# 32                           None
# 33                           None
# 34                           None
# 35                           None
# 36                           None
# 37                           None
# 38                           None
# 39                           None
# 40                           None
# 41                           None
# 42                           None
# 43                           line
# 44                           None
# 45                           None
# 46                           None
# 47                           line
# 48                           None
# 49                           None
# 50                           line
# 51                           None
# 52                           None
# 53                           line
# 54                           None
# 55                           line
# 56                           None
# 57                           line
# 58                           None
# 59                           None
#
# [60 rows x 450 columns]

# %% [markdown]
# You could notice that we received only 1 page, only 30 records. But this endpoint has muuuch more records in total. To get all the pages you should use a pagination.
#
# When working with APIs like GitHub, data is often returned in pages. Pagination allows you to retrieve all the data when an endpoint limits how much can be fetched at once.

# %% [markdown]
# ![1_D9K_aEWo9MDx7osLKT1Cxw.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **Pagination**
#
# GitHub has very good documentation, so it is not difficult to go through the documentation and find the relevant page: [Pagination.](https://docs.github.com/en/rest/using-the-rest-api/using-pagination-in-the-rest-api?apiVersion=2022-11-28)
#
# It says:
# >You can use the `link` header from the response to request additional pages of data.
#
# >The link header contains URLs that you can use to fetch additional pages of results. For example, the previous, next, first, and last page of results.

# %% [markdown]
# **GitHub API Pagination example**
#
# The GitHub API provides the `per_page` and `page` query parameters:
#
# * `per_page`: The number of records per page (up to 100).
# * `page`: The page number to retrieve.

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.headers
# Out:
# {'Date': 'Sat, 29 Mar 2025 07:20:32 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"b81399139d29f8c26369c8258c93ddfb0feafa6cc0e67fbe24b0d079f04dee8f"', 'Last-Modified': 'Fri, 28 Mar 2025 14:27:36 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/organizations/89419010/events?per_page=10&page=2>; rel="next", <https://api.github.com/organizations/89419010/events?per_page=10&page=30>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '48', 'X-RateLimit-Reset': '1743235730', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '12', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': '9D34:3EFBB3:59E2AB7:B3AE76A:67E79F40'}

# %% [markdown]
# Gotcha! We can see 'Link' in the headers. To get this link we can alternatively use `response.links`:

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.links
# Out:
# {'next': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=2',
#   'rel': 'next'},
#  'last': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=30',
#   'rel': 'last'}}

# %% [markdown]
# ### **dlt RESTClient**
#
# The response includes a 'Link' header for navigating to the next page.
# So now we can implement a pagination!
#
# When working with APIs, you could implement pagination using only Python and the requests library. While this approach works, it often requires writing boilerplate code for tasks like managing authentication, constructing URLs, and handling pagination logic.
#
# More about how to build pagination with Python and `requests`:
#
# * [Link 1](https://farnamdata.com/api-pagination)
#
# * [Link 2](https://www.klamp.io/blog/python-requests-pagination-for-efficient-data-retrieval)
#
# **But!** In this lesson, we’re gonna use dlt's **[RESTClient](https://dlthub.com/docs/general-usage/http/rest-client)** to handle pagination seamlessly when working with REST APIs like GitHub.
#
#
# **Why use RESTClient?**
#
# RESTClient is part of dlt's helpers, making it easier to interact with REST APIs by managing repetitive tasks such as:
#
# * Authentication
# * Query parameter handling
# * Pagination
#
# This reduces boilerplate code and lets you focus on your data pipeline logic.
#
# **Here’s how to fetch paginated data:**
# 1. Import RESTClient
# 2. Create the RESTClient instance
# 3. Use the `paginate` method to iterate through all pages of data.

# %%
from dlt.sources.helpers.rest_client import RESTClient


client = RESTClient(
    base_url="https://api.github.com",
)

for page in client.paginate("orgs/dlt-hub/events"):
    print(page)
    break
# Out:
# [{'id': '48083020508', 'type': 'WatchEvent', 'actor': {'id': 9391, 'login': 'benji-york', 'display_login': 'benji-york', 'gravatar_id': '', 'url': 'https://api.github.com/users/benji-york', 'avatar_url': 'https://avatars.githubusercontent.com/u/9391?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-03-28T14:27:36Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '48077813800', 'type': 'WatchEvent', 'actor': {'id': 1954680, 'login': 'arstercz', 'display_login': 'arstercz', 'gravatar_id': '', 'url': 'https://api.github.com/users/arstercz', 'avatar_url': 'https://avatars.githubusercontent.com/u/1954680?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-03-28T12:15:39Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '48074908511', 'type': 'WatchEvent', 'actor': {'id': 46582011, 'login': 'bhmilner', 'display_login': 'bhmilner', 'gravatar_id': '', 'url': 'https://api.github.com/users/bhmilner', 'avatar_url': 'https://avatars.githubusercontent.com/u/46582011?'}, 'repo': {'id': 791903865, 'name': 'dlt-hub/dlt-init-openapi', 'url': 'https://api.github.com/repos/dlt-hub/dlt-init-openapi'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-03-28T10:50:37Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '48073147341', 'type': 'IssuesEvent', 'actor': {'id': 42041832, 'login': 'abuchmueller', 'display_login': 'abuchmueller', 'gravatar_id': '', 'url': 'https://api.github.com/users/abuchmueller', 'avatar_url': 'https://avatars.githubusercontent.com/u/42041832?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'opened', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2452', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2452/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2452/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2452/events', 'html_url': 'https://github.com/dlt-hub/dlt/issues/2452', 'id': 2955625868, 'node_id': 'I_kwDOGvRYu86wK0WM', 'number': 2452, 'title': 'SQLAlchemy object in schema YAML causes deserialization error', 'user': {'login': 'abuchmueller', 'id': 42041832, 'node_id': 'MDQ6VXNlcjQyMDQxODMy', 'avatar_url': 'https://avatars.githubusercontent.com/u/42041832?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/abuchmueller', 'html_url': 'https://github.com/abuchmueller', 'followers_url': 'https://api.github.com/users/abuchmueller/followers', 'following_url': 'https://api.github.com/users/abuchmueller/following{/other_user}', 'gists_url': 'https://api.github.com/users/abuchmueller/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/abuchmueller/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/abuchmueller/subscriptions', 'organizations_url': 'https://api.github.com/users/abuchmueller/orgs', 'repos_url': 'https://api.github.com/users/abuchmueller/repos', 'events_url': 'https://api.github.com/users/abuchmueller/events{/privacy}', 'received_events_url': 'https://api.github.com/users/abuchmueller/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'com ...

# %% [markdown]
# Pagination type was detected automatically, but you can explicitly provide it:

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import HeaderLinkPaginator

client = RESTClient(
    base_url="https://api.github.com",
    paginator=HeaderLinkPaginator(),
)

# %% [markdown]
# The full list of available paginators you can see in offcial [dlt documentation](https://dlthub.com/docs/general-usage/http/rest-client#paginators).

# %% [markdown]
# ![Screenshot 2024-12-13 at 16.09.04.png](data:image/png;base64,...)

# %% [markdown]
# The events endpoint does not have as much data, specially if you compare it with the stargazers endpoint for the dlt repo.
#
# If you run the pipeline for stargazers endpoint, there is a high chance that you face the **rate limit error**.

# %%
from dlt.sources.helpers.rest_client import RESTClient


client = RESTClient(
    base_url="https://api.github.com",
)

for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    print(page)
# Out:
# [{'login': 'lalitpagaria', 'id': 19303690, 'node_id': 'MDQ6VXNlcjE5MzAzNjkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/19303690?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lalitpagaria', 'html_url': 'https://github.com/lalitpagaria', 'followers_url': 'https://api.github.com/users/lalitpagaria/followers', 'following_url': 'https://api.github.com/users/lalitpagaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/lalitpagaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lalitpagaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lalitpagaria/subscriptions', 'organizations_url': 'https://api.github.com/users/lalitpagaria/orgs', 'repos_url': 'https://api.github.com/users/lalitpagaria/repos', 'events_url': 'https://api.github.com/users/lalitpagaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lalitpagaria/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nikitavoloboev', 'id': 6391776, 'node_id': 'MDQ6VXNlcjYzOTE3NzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6391776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nikitavoloboev', 'html_url': 'https://github.com/nikitavoloboev', 'followers_url': 'https://api.github.com/users/nikitavoloboev/followers', 'following_url': 'https://api.github.com/users/nikitavoloboev/following{/other_user}', 'gists_url': 'https://api.github.com/users/nikitavoloboev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nikitavoloboev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nikitavoloboev/subscriptions', 'organizations_url': 'https://api.github.com/users/nikitavoloboev/orgs', 'repos_url': 'https://api.github.com/users/nikitavoloboev/repos', 'events_url': 'https://api.github.com/users/nikitavoloboev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nikitavoloboev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'gerrykou', 'id': 13572514, 'node_id': 'MDQ6VXNlcjEzNTcyNTE0', 'avatar_url': 'https://avatars.githubusercontent.com/u/13572514?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gerrykou', 'html_url': 'https://github.com/gerrykou', 'followers_url': 'https://api.github.com/users/gerrykou/followers', 'following_url': 'https://api.github.com/users/gerrykou/following{/other_user}', 'gists_url': 'https://api.github.com/users/gerrykou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gerrykou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gerrykou/subscriptions', 'organizations_url': 'https://api.github.com/users/gerrykou/orgs', 'repos_url': 'https://api.github.com/users/gerrykou/repos', 'events_url': 'https://api.github.com/users/gerrykou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gerrykou/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jdmonty', 'id': 3614077, 'node_id': 'MDQ6VXNlcjM2MTQwNzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3614077?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jdmonty', 'html_url': 'https://github.com/jdmonty', 'followers_url': 'https://api.github.com/users/jdmonty/followers', 'following_url': 'https://api.github.com/users/jdmonty/following{/other_user}', 'gists_url': 'https://api.github.com/users/jdmonty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jdmonty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jdmonty/subscriptions', 'organizations_url': 'https://api.github.com/users/jdmonty/orgs', 'repos_url': 'https://api.github.com/users/jdmonty/repos', 'events_url': 'https://api.github.com/users/jdmonty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jdmonty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login ...
# [{'login': 'jankatins', 'id': 890156, 'node_id': 'MDQ6VXNlcjg5MDE1Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/890156?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jankatins', 'html_url': 'https://github.com/jankatins', 'followers_url': 'https://api.github.com/users/jankatins/followers', 'following_url': 'https://api.github.com/users/jankatins/following{/other_user}', 'gists_url': 'https://api.github.com/users/jankatins/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jankatins/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jankatins/subscriptions', 'organizations_url': 'https://api.github.com/users/jankatins/orgs', 'repos_url': 'https://api.github.com/users/jankatins/repos', 'events_url': 'https://api.github.com/users/jankatins/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jankatins/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Tafkas', 'id': 34058, 'node_id': 'MDQ6VXNlcjM0MDU4', 'avatar_url': 'https://avatars.githubusercontent.com/u/34058?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Tafkas', 'html_url': 'https://github.com/Tafkas', 'followers_url': 'https://api.github.com/users/Tafkas/followers', 'following_url': 'https://api.github.com/users/Tafkas/following{/other_user}', 'gists_url': 'https://api.github.com/users/Tafkas/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Tafkas/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Tafkas/subscriptions', 'organizations_url': 'https://api.github.com/users/Tafkas/orgs', 'repos_url': 'https://api.github.com/users/Tafkas/repos', 'events_url': 'https://api.github.com/users/Tafkas/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Tafkas/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'chris-park', 'id': 58880657, 'node_id': 'MDQ6VXNlcjU4ODgwNjU3', 'avatar_url': 'https://avatars.githubusercontent.com/u/58880657?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chris-park', 'html_url': 'https://github.com/chris-park', 'followers_url': 'https://api.github.com/users/chris-park/followers', 'following_url': 'https://api.github.com/users/chris-park/following{/other_user}', 'gists_url': 'https://api.github.com/users/chris-park/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chris-park/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chris-park/subscriptions', 'organizations_url': 'https://api.github.com/users/chris-park/orgs', 'repos_url': 'https://api.github.com/users/chris-park/repos', 'events_url': 'https://api.github.com/users/chris-park/events{/privacy}', 'received_events_url': 'https://api.github.com/users/chris-park/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'ddeveloperr', 'id': 10800686, 'node_id': 'MDQ6VXNlcjEwODAwNjg2', 'avatar_url': 'https://avatars.githubusercontent.com/u/10800686?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ddeveloperr', 'html_url': 'https://github.com/ddeveloperr', 'followers_url': 'https://api.github.com/users/ddeveloperr/followers', 'following_url': 'https://api.github.com/users/ddeveloperr/following{/other_user}', 'gists_url': 'https://api.github.com/users/ddeveloperr/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ddeveloperr/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ddeveloperr/subscriptions', 'organizations_url': 'https://api.github.com/users/ddeveloperr/orgs', 'repos_url': 'https://api.github.com/users/ddeveloperr/repos', 'events_url': 'https://api.github.com/users/ddeveloperr/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ddeveloperr/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jpmmcneill', 'id': 55981540, 'node_id': 'MDQ6VXNlcjU1OTgxNTQw', 'a ...
# [{'login': 'z3z1ma', 'id': 41213451, 'node_id': 'MDQ6VXNlcjQxMjEzNDUx', 'avatar_url': 'https://avatars.githubusercontent.com/u/41213451?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/z3z1ma', 'html_url': 'https://github.com/z3z1ma', 'followers_url': 'https://api.github.com/users/z3z1ma/followers', 'following_url': 'https://api.github.com/users/z3z1ma/following{/other_user}', 'gists_url': 'https://api.github.com/users/z3z1ma/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/z3z1ma/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/z3z1ma/subscriptions', 'organizations_url': 'https://api.github.com/users/z3z1ma/orgs', 'repos_url': 'https://api.github.com/users/z3z1ma/repos', 'events_url': 'https://api.github.com/users/z3z1ma/events{/privacy}', 'received_events_url': 'https://api.github.com/users/z3z1ma/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'shimonymittal', 'id': 95504257, 'node_id': 'U_kgDOBbFHgQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/95504257?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/shimonymittal', 'html_url': 'https://github.com/shimonymittal', 'followers_url': 'https://api.github.com/users/shimonymittal/followers', 'following_url': 'https://api.github.com/users/shimonymittal/following{/other_user}', 'gists_url': 'https://api.github.com/users/shimonymittal/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/shimonymittal/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/shimonymittal/subscriptions', 'organizations_url': 'https://api.github.com/users/shimonymittal/orgs', 'repos_url': 'https://api.github.com/users/shimonymittal/repos', 'events_url': 'https://api.github.com/users/shimonymittal/events{/privacy}', 'received_events_url': 'https://api.github.com/users/shimonymittal/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'livioso', 'id': 1672198, 'node_id': 'MDQ6VXNlcjE2NzIxOTg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1672198?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/livioso', 'html_url': 'https://github.com/livioso', 'followers_url': 'https://api.github.com/users/livioso/followers', 'following_url': 'https://api.github.com/users/livioso/following{/other_user}', 'gists_url': 'https://api.github.com/users/livioso/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/livioso/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/livioso/subscriptions', 'organizations_url': 'https://api.github.com/users/livioso/orgs', 'repos_url': 'https://api.github.com/users/livioso/repos', 'events_url': 'https://api.github.com/users/livioso/events{/privacy}', 'received_events_url': 'https://api.github.com/users/livioso/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tungbq', 'id': 85242618, 'node_id': 'MDQ6VXNlcjg1MjQyNjE4', 'avatar_url': 'https://avatars.githubusercontent.com/u/85242618?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tungbq', 'html_url': 'https://github.com/tungbq', 'followers_url': 'https://api.github.com/users/tungbq/followers', 'following_url': 'https://api.github.com/users/tungbq/following{/other_user}', 'gists_url': 'https://api.github.com/users/tungbq/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tungbq/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tungbq/subscriptions', 'organizations_url': 'https://api.github.com/users/tungbq/orgs', 'repos_url': 'https://api.github.com/users/tungbq/repos', 'events_url': 'https://api.github.com/users/tungbq/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tungbq/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'VincenzoGalante', 'id': 79586031, 'node_id': 'MDQ6VXNlcjc5NTg2MDMx', 'avatar_url': 'https://avatars.githubuser ...
# [{'login': 'yliapis', 'id': 14884413, 'node_id': 'MDQ6VXNlcjE0ODg0NDEz', 'avatar_url': 'https://avatars.githubusercontent.com/u/14884413?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/yliapis', 'html_url': 'https://github.com/yliapis', 'followers_url': 'https://api.github.com/users/yliapis/followers', 'following_url': 'https://api.github.com/users/yliapis/following{/other_user}', 'gists_url': 'https://api.github.com/users/yliapis/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/yliapis/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/yliapis/subscriptions', 'organizations_url': 'https://api.github.com/users/yliapis/orgs', 'repos_url': 'https://api.github.com/users/yliapis/repos', 'events_url': 'https://api.github.com/users/yliapis/events{/privacy}', 'received_events_url': 'https://api.github.com/users/yliapis/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'thisisdope', 'id': 32782533, 'node_id': 'MDQ6VXNlcjMyNzgyNTMz', 'avatar_url': 'https://avatars.githubusercontent.com/u/32782533?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/thisisdope', 'html_url': 'https://github.com/thisisdope', 'followers_url': 'https://api.github.com/users/thisisdope/followers', 'following_url': 'https://api.github.com/users/thisisdope/following{/other_user}', 'gists_url': 'https://api.github.com/users/thisisdope/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/thisisdope/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/thisisdope/subscriptions', 'organizations_url': 'https://api.github.com/users/thisisdope/orgs', 'repos_url': 'https://api.github.com/users/thisisdope/repos', 'events_url': 'https://api.github.com/users/thisisdope/events{/privacy}', 'received_events_url': 'https://api.github.com/users/thisisdope/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tconbeer', 'id': 705906, 'node_id': 'MDQ6VXNlcjcwNTkwNg==', 'avatar_url': 'https://avatars.githubusercontent.com/u/705906?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tconbeer', 'html_url': 'https://github.com/tconbeer', 'followers_url': 'https://api.github.com/users/tconbeer/followers', 'following_url': 'https://api.github.com/users/tconbeer/following{/other_user}', 'gists_url': 'https://api.github.com/users/tconbeer/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tconbeer/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tconbeer/subscriptions', 'organizations_url': 'https://api.github.com/users/tconbeer/orgs', 'repos_url': 'https://api.github.com/users/tconbeer/repos', 'events_url': 'https://api.github.com/users/tconbeer/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tconbeer/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'davidharting', 'id': 6146772, 'node_id': 'MDQ6VXNlcjYxNDY3NzI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6146772?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/davidharting', 'html_url': 'https://github.com/davidharting', 'followers_url': 'https://api.github.com/users/davidharting/followers', 'following_url': 'https://api.github.com/users/davidharting/following{/other_user}', 'gists_url': 'https://api.github.com/users/davidharting/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/davidharting/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/davidharting/subscriptions', 'organizations_url': 'https://api.github.com/users/davidharting/orgs', 'repos_url': 'https://api.github.com/users/davidharting/repos', 'events_url': 'https://api.github.com/users/davidharting/events{/privacy}', 'received_events_url': 'https://api.github.com/users/davidharting/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'kwigley', 'id': 9877221, 'node_id': 'MDQ6VXNlc ...
# [{'login': 'mrnitrate', 'id': 1325392, 'node_id': 'MDQ6VXNlcjEzMjUzOTI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1325392?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mrnitrate', 'html_url': 'https://github.com/mrnitrate', 'followers_url': 'https://api.github.com/users/mrnitrate/followers', 'following_url': 'https://api.github.com/users/mrnitrate/following{/other_user}', 'gists_url': 'https://api.github.com/users/mrnitrate/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mrnitrate/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mrnitrate/subscriptions', 'organizations_url': 'https://api.github.com/users/mrnitrate/orgs', 'repos_url': 'https://api.github.com/users/mrnitrate/repos', 'events_url': 'https://api.github.com/users/mrnitrate/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mrnitrate/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'unarmedcivilian', 'id': 8530446, 'node_id': 'MDQ6VXNlcjg1MzA0NDY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8530446?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/unarmedcivilian', 'html_url': 'https://github.com/unarmedcivilian', 'followers_url': 'https://api.github.com/users/unarmedcivilian/followers', 'following_url': 'https://api.github.com/users/unarmedcivilian/following{/other_user}', 'gists_url': 'https://api.github.com/users/unarmedcivilian/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/unarmedcivilian/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/unarmedcivilian/subscriptions', 'organizations_url': 'https://api.github.com/users/unarmedcivilian/orgs', 'repos_url': 'https://api.github.com/users/unarmedcivilian/repos', 'events_url': 'https://api.github.com/users/unarmedcivilian/events{/privacy}', 'received_events_url': 'https://api.github.com/users/unarmedcivilian/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'abhilashchowdhary', 'id': 18218120, 'node_id': 'MDQ6VXNlcjE4MjE4MTIw', 'avatar_url': 'https://avatars.githubusercontent.com/u/18218120?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/abhilashchowdhary', 'html_url': 'https://github.com/abhilashchowdhary', 'followers_url': 'https://api.github.com/users/abhilashchowdhary/followers', 'following_url': 'https://api.github.com/users/abhilashchowdhary/following{/other_user}', 'gists_url': 'https://api.github.com/users/abhilashchowdhary/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/abhilashchowdhary/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/abhilashchowdhary/subscriptions', 'organizations_url': 'https://api.github.com/users/abhilashchowdhary/orgs', 'repos_url': 'https://api.github.com/users/abhilashchowdhary/repos', 'events_url': 'https://api.github.com/users/abhilashchowdhary/events{/privacy}', 'received_events_url': 'https://api.github.com/users/abhilashchowdhary/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jckail', 'id': 13952435, 'node_id': 'MDQ6VXNlcjEzOTUyNDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/13952435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jckail', 'html_url': 'https://github.com/jckail', 'followers_url': 'https://api.github.com/users/jckail/followers', 'following_url': 'https://api.github.com/users/jckail/following{/other_user}', 'gists_url': 'https://api.github.com/users/jckail/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jckail/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jckail/subscriptions', 'organizations_url': 'https://api.github.com/users/jckail/orgs', 'repos_url': 'https://api.github.com/users/jckail/repos', 'events_url': 'https://api.github.com/users/jckail/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jckail/received_events', ' ...
# [{'login': 'adrivn', 'id': 42723006, 'node_id': 'MDQ6VXNlcjQyNzIzMDA2', 'avatar_url': 'https://avatars.githubusercontent.com/u/42723006?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/adrivn', 'html_url': 'https://github.com/adrivn', 'followers_url': 'https://api.github.com/users/adrivn/followers', 'following_url': 'https://api.github.com/users/adrivn/following{/other_user}', 'gists_url': 'https://api.github.com/users/adrivn/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/adrivn/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/adrivn/subscriptions', 'organizations_url': 'https://api.github.com/users/adrivn/orgs', 'repos_url': 'https://api.github.com/users/adrivn/repos', 'events_url': 'https://api.github.com/users/adrivn/events{/privacy}', 'received_events_url': 'https://api.github.com/users/adrivn/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Conq1', 'id': 19863623, 'node_id': 'MDQ6VXNlcjE5ODYzNjIz', 'avatar_url': 'https://avatars.githubusercontent.com/u/19863623?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Conq1', 'html_url': 'https://github.com/Conq1', 'followers_url': 'https://api.github.com/users/Conq1/followers', 'following_url': 'https://api.github.com/users/Conq1/following{/other_user}', 'gists_url': 'https://api.github.com/users/Conq1/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Conq1/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Conq1/subscriptions', 'organizations_url': 'https://api.github.com/users/Conq1/orgs', 'repos_url': 'https://api.github.com/users/Conq1/repos', 'events_url': 'https://api.github.com/users/Conq1/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Conq1/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tiagotcunha', 'id': 10522134, 'node_id': 'MDQ6VXNlcjEwNTIyMTM0', 'avatar_url': 'https://avatars.githubusercontent.com/u/10522134?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tiagotcunha', 'html_url': 'https://github.com/tiagotcunha', 'followers_url': 'https://api.github.com/users/tiagotcunha/followers', 'following_url': 'https://api.github.com/users/tiagotcunha/following{/other_user}', 'gists_url': 'https://api.github.com/users/tiagotcunha/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tiagotcunha/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tiagotcunha/subscriptions', 'organizations_url': 'https://api.github.com/users/tiagotcunha/orgs', 'repos_url': 'https://api.github.com/users/tiagotcunha/repos', 'events_url': 'https://api.github.com/users/tiagotcunha/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tiagotcunha/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'dvd3v', 'id': 16576928, 'node_id': 'MDQ6VXNlcjE2NTc2OTI4', 'avatar_url': 'https://avatars.githubusercontent.com/u/16576928?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dvd3v', 'html_url': 'https://github.com/dvd3v', 'followers_url': 'https://api.github.com/users/dvd3v/followers', 'following_url': 'https://api.github.com/users/dvd3v/following{/other_user}', 'gists_url': 'https://api.github.com/users/dvd3v/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dvd3v/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dvd3v/subscriptions', 'organizations_url': 'https://api.github.com/users/dvd3v/orgs', 'repos_url': 'https://api.github.com/users/dvd3v/repos', 'events_url': 'https://api.github.com/users/dvd3v/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dvd3v/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'macraesdirtysocks', 'id': 78040749, 'node_id': 'MDQ6VXNlcjc4MDQwNzQ5', 'avatar_url': 'https://avatars.githubusercontent.com/u/78040749?v=4', 'gravatar_id': '',  ...
# [{'login': 'pbadeer', 'id': 467756, 'node_id': 'MDQ6VXNlcjQ2Nzc1Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/467756?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/pbadeer', 'html_url': 'https://github.com/pbadeer', 'followers_url': 'https://api.github.com/users/pbadeer/followers', 'following_url': 'https://api.github.com/users/pbadeer/following{/other_user}', 'gists_url': 'https://api.github.com/users/pbadeer/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/pbadeer/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/pbadeer/subscriptions', 'organizations_url': 'https://api.github.com/users/pbadeer/orgs', 'repos_url': 'https://api.github.com/users/pbadeer/repos', 'events_url': 'https://api.github.com/users/pbadeer/events{/privacy}', 'received_events_url': 'https://api.github.com/users/pbadeer/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'cuddebtj', 'id': 65567376, 'node_id': 'MDQ6VXNlcjY1NTY3Mzc2', 'avatar_url': 'https://avatars.githubusercontent.com/u/65567376?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cuddebtj', 'html_url': 'https://github.com/cuddebtj', 'followers_url': 'https://api.github.com/users/cuddebtj/followers', 'following_url': 'https://api.github.com/users/cuddebtj/following{/other_user}', 'gists_url': 'https://api.github.com/users/cuddebtj/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cuddebtj/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cuddebtj/subscriptions', 'organizations_url': 'https://api.github.com/users/cuddebtj/orgs', 'repos_url': 'https://api.github.com/users/cuddebtj/repos', 'events_url': 'https://api.github.com/users/cuddebtj/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cuddebtj/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'let-me-cook', 'id': 35270908, 'node_id': 'MDQ6VXNlcjM1MjcwOTA4', 'avatar_url': 'https://avatars.githubusercontent.com/u/35270908?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/let-me-cook', 'html_url': 'https://github.com/let-me-cook', 'followers_url': 'https://api.github.com/users/let-me-cook/followers', 'following_url': 'https://api.github.com/users/let-me-cook/following{/other_user}', 'gists_url': 'https://api.github.com/users/let-me-cook/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/let-me-cook/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/let-me-cook/subscriptions', 'organizations_url': 'https://api.github.com/users/let-me-cook/orgs', 'repos_url': 'https://api.github.com/users/let-me-cook/repos', 'events_url': 'https://api.github.com/users/let-me-cook/events{/privacy}', 'received_events_url': 'https://api.github.com/users/let-me-cook/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'il-dat', 'id': 103571964, 'node_id': 'U_kgDOBixh_A', 'avatar_url': 'https://avatars.githubusercontent.com/u/103571964?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/il-dat', 'html_url': 'https://github.com/il-dat', 'followers_url': 'https://api.github.com/users/il-dat/followers', 'following_url': 'https://api.github.com/users/il-dat/following{/other_user}', 'gists_url': 'https://api.github.com/users/il-dat/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/il-dat/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/il-dat/subscriptions', 'organizations_url': 'https://api.github.com/users/il-dat/orgs', 'repos_url': 'https://api.github.com/users/il-dat/repos', 'events_url': 'https://api.github.com/users/il-dat/events{/privacy}', 'received_events_url': 'https://api.github.com/users/il-dat/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'rogegoncalves', 'id': 33241020, 'node_id': 'MDQ6VXNlcjMzMjQxMDIw', 'avatar_url': 'https://avatars.githubuserco ...
# [{'login': 'mesmacosta', 'id': 3176836, 'node_id': 'MDQ6VXNlcjMxNzY4MzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3176836?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mesmacosta', 'html_url': 'https://github.com/mesmacosta', 'followers_url': 'https://api.github.com/users/mesmacosta/followers', 'following_url': 'https://api.github.com/users/mesmacosta/following{/other_user}', 'gists_url': 'https://api.github.com/users/mesmacosta/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mesmacosta/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mesmacosta/subscriptions', 'organizations_url': 'https://api.github.com/users/mesmacosta/orgs', 'repos_url': 'https://api.github.com/users/mesmacosta/repos', 'events_url': 'https://api.github.com/users/mesmacosta/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mesmacosta/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'samg861', 'id': 16475396, 'node_id': 'MDQ6VXNlcjE2NDc1Mzk2', 'avatar_url': 'https://avatars.githubusercontent.com/u/16475396?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/samg861', 'html_url': 'https://github.com/samg861', 'followers_url': 'https://api.github.com/users/samg861/followers', 'following_url': 'https://api.github.com/users/samg861/following{/other_user}', 'gists_url': 'https://api.github.com/users/samg861/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/samg861/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/samg861/subscriptions', 'organizations_url': 'https://api.github.com/users/samg861/orgs', 'repos_url': 'https://api.github.com/users/samg861/repos', 'events_url': 'https://api.github.com/users/samg861/events{/privacy}', 'received_events_url': 'https://api.github.com/users/samg861/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'itroulli', 'id': 15125321, 'node_id': 'MDQ6VXNlcjE1MTI1MzIx', 'avatar_url': 'https://avatars.githubusercontent.com/u/15125321?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/itroulli', 'html_url': 'https://github.com/itroulli', 'followers_url': 'https://api.github.com/users/itroulli/followers', 'following_url': 'https://api.github.com/users/itroulli/following{/other_user}', 'gists_url': 'https://api.github.com/users/itroulli/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/itroulli/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/itroulli/subscriptions', 'organizations_url': 'https://api.github.com/users/itroulli/orgs', 'repos_url': 'https://api.github.com/users/itroulli/repos', 'events_url': 'https://api.github.com/users/itroulli/events{/privacy}', 'received_events_url': 'https://api.github.com/users/itroulli/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'match-gabeflores', 'id': 286903, 'node_id': 'MDQ6VXNlcjI4NjkwMw==', 'avatar_url': 'https://avatars.githubusercontent.com/u/286903?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/match-gabeflores', 'html_url': 'https://github.com/match-gabeflores', 'followers_url': 'https://api.github.com/users/match-gabeflores/followers', 'following_url': 'https://api.github.com/users/match-gabeflores/following{/other_user}', 'gists_url': 'https://api.github.com/users/match-gabeflores/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/match-gabeflores/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/match-gabeflores/subscriptions', 'organizations_url': 'https://api.github.com/users/match-gabeflores/orgs', 'repos_url': 'https://api.github.com/users/match-gabeflores/repos', 'events_url': 'https://api.github.com/users/match-gabeflores/events{/privacy}', 'received_events_url': 'https://api.github.com/users/match-gabeflores/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': ...
# [{'login': 'usr-av', 'id': 14003879, 'node_id': 'MDQ6VXNlcjE0MDAzODc5', 'avatar_url': 'https://avatars.githubusercontent.com/u/14003879?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/usr-av', 'html_url': 'https://github.com/usr-av', 'followers_url': 'https://api.github.com/users/usr-av/followers', 'following_url': 'https://api.github.com/users/usr-av/following{/other_user}', 'gists_url': 'https://api.github.com/users/usr-av/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/usr-av/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/usr-av/subscriptions', 'organizations_url': 'https://api.github.com/users/usr-av/orgs', 'repos_url': 'https://api.github.com/users/usr-av/repos', 'events_url': 'https://api.github.com/users/usr-av/events{/privacy}', 'received_events_url': 'https://api.github.com/users/usr-av/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'datarise', 'id': 57174695, 'node_id': 'MDQ6VXNlcjU3MTc0Njk1', 'avatar_url': 'https://avatars.githubusercontent.com/u/57174695?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/datarise', 'html_url': 'https://github.com/datarise', 'followers_url': 'https://api.github.com/users/datarise/followers', 'following_url': 'https://api.github.com/users/datarise/following{/other_user}', 'gists_url': 'https://api.github.com/users/datarise/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/datarise/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/datarise/subscriptions', 'organizations_url': 'https://api.github.com/users/datarise/orgs', 'repos_url': 'https://api.github.com/users/datarise/repos', 'events_url': 'https://api.github.com/users/datarise/events{/privacy}', 'received_events_url': 'https://api.github.com/users/datarise/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'ancestor-mithril', 'id': 58839912, 'node_id': 'MDQ6VXNlcjU4ODM5OTEy', 'avatar_url': 'https://avatars.githubusercontent.com/u/58839912?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ancestor-mithril', 'html_url': 'https://github.com/ancestor-mithril', 'followers_url': 'https://api.github.com/users/ancestor-mithril/followers', 'following_url': 'https://api.github.com/users/ancestor-mithril/following{/other_user}', 'gists_url': 'https://api.github.com/users/ancestor-mithril/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ancestor-mithril/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ancestor-mithril/subscriptions', 'organizations_url': 'https://api.github.com/users/ancestor-mithril/orgs', 'repos_url': 'https://api.github.com/users/ancestor-mithril/repos', 'events_url': 'https://api.github.com/users/ancestor-mithril/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ancestor-mithril/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'prratek', 'id': 34848565, 'node_id': 'MDQ6VXNlcjM0ODQ4NTY1', 'avatar_url': 'https://avatars.githubusercontent.com/u/34848565?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/prratek', 'html_url': 'https://github.com/prratek', 'followers_url': 'https://api.github.com/users/prratek/followers', 'following_url': 'https://api.github.com/users/prratek/following{/other_user}', 'gists_url': 'https://api.github.com/users/prratek/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/prratek/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/prratek/subscriptions', 'organizations_url': 'https://api.github.com/users/prratek/orgs', 'repos_url': 'https://api.github.com/users/prratek/repos', 'events_url': 'https://api.github.com/users/prratek/events{/privacy}', 'received_events_url': 'https://api.github.com/users/prratek/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'hamis-sephora', 'id': 99803963, 'node_id ...
# [{'login': 'mid', 'id': 3770, 'node_id': 'MDQ6VXNlcjM3NzA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3770?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mid', 'html_url': 'https://github.com/mid', 'followers_url': 'https://api.github.com/users/mid/followers', 'following_url': 'https://api.github.com/users/mid/following{/other_user}', 'gists_url': 'https://api.github.com/users/mid/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mid/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mid/subscriptions', 'organizations_url': 'https://api.github.com/users/mid/orgs', 'repos_url': 'https://api.github.com/users/mid/repos', 'events_url': 'https://api.github.com/users/mid/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mid/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jazzwang', 'id': 76903, 'node_id': 'MDQ6VXNlcjc2OTAz', 'avatar_url': 'https://avatars.githubusercontent.com/u/76903?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jazzwang', 'html_url': 'https://github.com/jazzwang', 'followers_url': 'https://api.github.com/users/jazzwang/followers', 'following_url': 'https://api.github.com/users/jazzwang/following{/other_user}', 'gists_url': 'https://api.github.com/users/jazzwang/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jazzwang/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jazzwang/subscriptions', 'organizations_url': 'https://api.github.com/users/jazzwang/orgs', 'repos_url': 'https://api.github.com/users/jazzwang/repos', 'events_url': 'https://api.github.com/users/jazzwang/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jazzwang/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'damireh', 'id': 429845, 'node_id': 'MDQ6VXNlcjQyOTg0NQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/429845?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/damireh', 'html_url': 'https://github.com/damireh', 'followers_url': 'https://api.github.com/users/damireh/followers', 'following_url': 'https://api.github.com/users/damireh/following{/other_user}', 'gists_url': 'https://api.github.com/users/damireh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/damireh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/damireh/subscriptions', 'organizations_url': 'https://api.github.com/users/damireh/orgs', 'repos_url': 'https://api.github.com/users/damireh/repos', 'events_url': 'https://api.github.com/users/damireh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/damireh/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'cfahlgren1', 'id': 13546028, 'node_id': 'MDQ6VXNlcjEzNTQ2MDI4', 'avatar_url': 'https://avatars.githubusercontent.com/u/13546028?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cfahlgren1', 'html_url': 'https://github.com/cfahlgren1', 'followers_url': 'https://api.github.com/users/cfahlgren1/followers', 'following_url': 'https://api.github.com/users/cfahlgren1/following{/other_user}', 'gists_url': 'https://api.github.com/users/cfahlgren1/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cfahlgren1/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cfahlgren1/subscriptions', 'organizations_url': 'https://api.github.com/users/cfahlgren1/orgs', 'repos_url': 'https://api.github.com/users/cfahlgren1/repos', 'events_url': 'https://api.github.com/users/cfahlgren1/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cfahlgren1/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'kinsvater', 'id': 17121248, 'node_id': 'MDQ6VXNlcjE3MTIxMjQ4', 'avatar_url': 'https://avatars.githubusercontent.com/u/17121248?v=4', 'gravatar_id': '', 'url': 'https://api.gi ...
# [{'login': 'Albayrakengin', 'id': 88938152, 'node_id': 'MDQ6VXNlcjg4OTM4MTUy', 'avatar_url': 'https://avatars.githubusercontent.com/u/88938152?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Albayrakengin', 'html_url': 'https://github.com/Albayrakengin', 'followers_url': 'https://api.github.com/users/Albayrakengin/followers', 'following_url': 'https://api.github.com/users/Albayrakengin/following{/other_user}', 'gists_url': 'https://api.github.com/users/Albayrakengin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Albayrakengin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Albayrakengin/subscriptions', 'organizations_url': 'https://api.github.com/users/Albayrakengin/orgs', 'repos_url': 'https://api.github.com/users/Albayrakengin/repos', 'events_url': 'https://api.github.com/users/Albayrakengin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Albayrakengin/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'aerofeev', 'id': 6343458, 'node_id': 'MDQ6VXNlcjYzNDM0NTg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6343458?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aerofeev', 'html_url': 'https://github.com/aerofeev', 'followers_url': 'https://api.github.com/users/aerofeev/followers', 'following_url': 'https://api.github.com/users/aerofeev/following{/other_user}', 'gists_url': 'https://api.github.com/users/aerofeev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aerofeev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aerofeev/subscriptions', 'organizations_url': 'https://api.github.com/users/aerofeev/orgs', 'repos_url': 'https://api.github.com/users/aerofeev/repos', 'events_url': 'https://api.github.com/users/aerofeev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aerofeev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'bayees', 'id': 1546610, 'node_id': 'MDQ6VXNlcjE1NDY2MTA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1546610?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/bayees', 'html_url': 'https://github.com/bayees', 'followers_url': 'https://api.github.com/users/bayees/followers', 'following_url': 'https://api.github.com/users/bayees/following{/other_user}', 'gists_url': 'https://api.github.com/users/bayees/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/bayees/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/bayees/subscriptions', 'organizations_url': 'https://api.github.com/users/bayees/orgs', 'repos_url': 'https://api.github.com/users/bayees/repos', 'events_url': 'https://api.github.com/users/bayees/events{/privacy}', 'received_events_url': 'https://api.github.com/users/bayees/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'asavitski', 'id': 4550995, 'node_id': 'MDQ6VXNlcjQ1NTA5OTU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4550995?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/asavitski', 'html_url': 'https://github.com/asavitski', 'followers_url': 'https://api.github.com/users/asavitski/followers', 'following_url': 'https://api.github.com/users/asavitski/following{/other_user}', 'gists_url': 'https://api.github.com/users/asavitski/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/asavitski/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/asavitski/subscriptions', 'organizations_url': 'https://api.github.com/users/asavitski/orgs', 'repos_url': 'https://api.github.com/users/asavitski/repos', 'events_url': 'https://api.github.com/users/asavitski/events{/privacy}', 'received_events_url': 'https://api.github.com/users/asavitski/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'rl-algo-trader', 'id': 89914516, 'node_id': 'MDQ6VXNlcjg5O ...
# ...
# [{'login': 'rmax', 'id': 26015, 'node_id': 'MDQ6VXNlcjI2MDE1', 'avatar_url': 'https://avatars.githubusercontent.com/u/26015?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rmax', 'html_url': 'https://github.com/rmax', 'followers_url': 'https://api.github.com/users/rmax/followers', 'following_url': 'https://api.github.com/users/rmax/following{/other_user}', 'gists_url': 'https://api.github.com/users/rmax/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rmax/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rmax/subscriptions', 'organizations_url': 'https://api.github.com/users/rmax/orgs', 'repos_url': 'https://api.github.com/users/rmax/repos', 'events_url': 'https://api.github.com/users/rmax/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rmax/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'matthauskrzykowski', 'id': 18119107, 'node_id': 'MDQ6VXNlcjE4MTE5MTA3', 'avatar_url': 'https://avatars.githubusercontent.com/u/18119107?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/matthauskrzykowski', 'html_url': 'https://github.com/matthauskrzykowski', 'followers_url': 'https://api.github.com/users/matthauskrzykowski/followers', 'following_url': 'https://api.github.com/users/matthauskrzykowski/following{/other_user}', 'gists_url': 'https://api.github.com/users/matthauskrzykowski/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/matthauskrzykowski/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/matthauskrzykowski/subscriptions', 'organizations_url': 'https://api.github.com/users/matthauskrzykowski/orgs', 'repos_url': 'https://api.github.com/users/matthauskrzykowski/repos', 'events_url': 'https://api.github.com/users/matthauskrzykowski/events{/privacy}', 'received_events_url': 'https://api.github.com/users/matthauskrzykowski/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'grateful-dev', 'id': 49768627, 'node_id': 'MDQ6VXNlcjQ5NzY4NjI3', 'avatar_url': 'https://avatars.githubusercontent.com/u/49768627?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/grateful-dev', 'html_url': 'https://github.com/grateful-dev', 'followers_url': 'https://api.github.com/users/grateful-dev/followers', 'following_url': 'https://api.github.com/users/grateful-dev/following{/other_user}', 'gists_url': 'https://api.github.com/users/grateful-dev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/grateful-dev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/grateful-dev/subscriptions', 'organizations_url': 'https://api.github.com/users/grateful-dev/orgs', 'repos_url': 'https://api.github.com/users/grateful-dev/repos', 'events_url': 'https://api.github.com/users/grateful-dev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/grateful-dev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'eliasdefaria', 'id': 30669330, 'node_id': 'MDQ6VXNlcjMwNjY5MzMw', 'avatar_url': 'https://avatars.githubusercontent.com/u/30669330?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/eliasdefaria', 'html_url': 'https://github.com/eliasdefaria', 'followers_url': 'https://api.github.com/users/eliasdefaria/followers', 'following_url': 'https://api.github.com/users/eliasdefaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/eliasdefaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/eliasdefaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/eliasdefaria/subscriptions', 'organizations_url': 'https://api.github.com/users/eliasdefaria/orgs', 'repos_url': 'https://api.github.com/users/eliasdefaria/repos', 'events_url': 'https://api.github.com/users/eliasdefaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/eliasdefaria/received_events', 'type': 'User', 'us ...
# [{'login': 'harrydevforlife', 'id': 87957596, 'node_id': 'MDQ6VXNlcjg3OTU3NTk2', 'avatar_url': 'https://avatars.githubusercontent.com/u/87957596?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/harrydevforlife', 'html_url': 'https://github.com/harrydevforlife', 'followers_url': 'https://api.github.com/users/harrydevforlife/followers', 'following_url': 'https://api.github.com/users/harrydevforlife/following{/other_user}', 'gists_url': 'https://api.github.com/users/harrydevforlife/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/harrydevforlife/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/harrydevforlife/subscriptions', 'organizations_url': 'https://api.github.com/users/harrydevforlife/orgs', 'repos_url': 'https://api.github.com/users/harrydevforlife/repos', 'events_url': 'https://api.github.com/users/harrydevforlife/events{/privacy}', 'received_events_url': 'https://api.github.com/users/harrydevforlife/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'xavman6', 'id': 90087639, 'node_id': 'MDQ6VXNlcjkwMDg3NjM5', 'avatar_url': 'https://avatars.githubusercontent.com/u/90087639?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/xavman6', 'html_url': 'https://github.com/xavman6', 'followers_url': 'https://api.github.com/users/xavman6/followers', 'following_url': 'https://api.github.com/users/xavman6/following{/other_user}', 'gists_url': 'https://api.github.com/users/xavman6/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/xavman6/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/xavman6/subscriptions', 'organizations_url': 'https://api.github.com/users/xavman6/orgs', 'repos_url': 'https://api.github.com/users/xavman6/repos', 'events_url': 'https://api.github.com/users/xavman6/events{/privacy}', 'received_events_url': 'https://api.github.com/users/xavman6/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'rohitdev', 'id': 1487886, 'node_id': 'MDQ6VXNlcjE0ODc4ODY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1487886?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rohitdev', 'html_url': 'https://github.com/rohitdev', 'followers_url': 'https://api.github.com/users/rohitdev/followers', 'following_url': 'https://api.github.com/users/rohitdev/following{/other_user}', 'gists_url': 'https://api.github.com/users/rohitdev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rohitdev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rohitdev/subscriptions', 'organizations_url': 'https://api.github.com/users/rohitdev/orgs', 'repos_url': 'https://api.github.com/users/rohitdev/repos', 'events_url': 'https://api.github.com/users/rohitdev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rohitdev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'GregMisfitsMarket', 'id': 67428388, 'node_id': 'MDQ6VXNlcjY3NDI4Mzg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/67428388?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/GregMisfitsMarket', 'html_url': 'https://github.com/GregMisfitsMarket', 'followers_url': 'https://api.github.com/users/GregMisfitsMarket/followers', 'following_url': 'https://api.github.com/users/GregMisfitsMarket/following{/other_user}', 'gists_url': 'https://api.github.com/users/GregMisfitsMarket/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/GregMisfitsMarket/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/GregMisfitsMarket/subscriptions', 'organizations_url': 'https://api.github.com/users/GregMisfitsMarket/orgs', 'repos_url': 'https://api.github.com/users/GregMisfitsMarket/repos', 'events_url': 'https://api.github.com/users/GregMisfitsMarket/events{/privacy}', 'received_events_url': 'https://api.github.com/users/GregMisfitsMarket/received_events', ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-9b37d2b2fdbc> in <cell line: 0>()
#       6 )
#       7
# ----> 8 for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
#       9     print(page)
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, headers, **kwargs)
#     236         while True:
#     237             try:
# --> 238                 response = self._send_request(request, **kwargs)
#     239             except IgnoreResponseException:
#     240                 break
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in _send_request(self, request, **kwargs)
#     142
#     143         send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 144         return self.session.send(prepared_request, **send_kwargs)
#     145
#     146     def request(self, path: str = "", method: HTTPMethod = "GET", **kwargs: Any) -> Response:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/requests/session.py in send(self, request, **kwargs)
#      59     def send(self, request, **kwargs):  # type: ignore[no-untyped-def]
#      60         kwargs.setdefault("timeout", self.timeout)
# ---> 61         return super().send(request, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     708
#     709         # Response manipulation hooks
# --> 710         r = dispatch_hook("response", hooks, r, **kwargs)
#     711
#     712         # Persist cookies
#
# /usr/local/lib/python3.11/dist-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28             hooks = [hooks]
#      29         for hook in hooks:
# ---> 30             _hook_data = hook(hook_data, **kwargs)
#      31             if _hook_data is not None:
#      32                 hook_data = _hook_data
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in raise_for_status(response, *args, **kwargs)
#     327
#     328 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 329     response.raise_for_status()
#     330
#     331
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1022
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#    1026     def close(self):
#
# HTTPError: 403 Client Error: rate limit exceeded for url: https://api.github.com/repositories/452221115/stargazers?page=61

# %% [markdown]
# ### **Exercise 1: Pagination with RESTClient**
# Explore the cells above and answer the question below.
# #### Question
# What type of pagination should we use for the GitHub API?

# %% [markdown]
# ## **Authentication**
#
# To avoid this error you can use [GitHub API Authentication](https://docs.github.com/en/rest/authentication/authenticating-to-the-rest-api?apiVersion=2022-11-28):
#
# 1. Login to your GitHub account.
# 2. Generate [API token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token) (classic one!).
# 2.  Use it as an access token for GitHub API.

# %% [markdown]
# **! ATTENTION !**
#
# Never share your credentials in public and never hard-code them in your code. Use **environment variables** or **dlt secrets.toml**.

# %% [markdown]
# Create an environment variable for your access token.
#
# ![1_5wEevNCOf80GTHwptPTB4g.webp](data:image/webp;base64,...)
#
# If you have your token [ready in Colab](https://medium.com/@parthdasawant/how-to-use-secrets-in-google-colab-450c38e3ec75), you can directly use it:

# %%
import os
from google.colab import userdata

access_token = userdata.get('github_api')

# %% [markdown]
# So now you can use `access_token` variable in the code below:

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


client = RESTClient(
    base_url="https://api.github.com",
    auth=BearerTokenAuth(token=access_token) # <--- put your token here
)

for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    print(page)
    break
# Out:
# [{'login': 'lalitpagaria', 'id': 19303690, 'node_id': 'MDQ6VXNlcjE5MzAzNjkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/19303690?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lalitpagaria', 'html_url': 'https://github.com/lalitpagaria', 'followers_url': 'https://api.github.com/users/lalitpagaria/followers', 'following_url': 'https://api.github.com/users/lalitpagaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/lalitpagaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lalitpagaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lalitpagaria/subscriptions', 'organizations_url': 'https://api.github.com/users/lalitpagaria/orgs', 'repos_url': 'https://api.github.com/users/lalitpagaria/repos', 'events_url': 'https://api.github.com/users/lalitpagaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lalitpagaria/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nikitavoloboev', 'id': 6391776, 'node_id': 'MDQ6VXNlcjYzOTE3NzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6391776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nikitavoloboev', 'html_url': 'https://github.com/nikitavoloboev', 'followers_url': 'https://api.github.com/users/nikitavoloboev/followers', 'following_url': 'https://api.github.com/users/nikitavoloboev/following{/other_user}', 'gists_url': 'https://api.github.com/users/nikitavoloboev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nikitavoloboev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nikitavoloboev/subscriptions', 'organizations_url': 'https://api.github.com/users/nikitavoloboev/orgs', 'repos_url': 'https://api.github.com/users/nikitavoloboev/repos', 'events_url': 'https://api.github.com/users/nikitavoloboev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nikitavoloboev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'gerrykou', 'id': 13572514, 'node_id': 'MDQ6VXNlcjEzNTcyNTE0', 'avatar_url': 'https://avatars.githubusercontent.com/u/13572514?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gerrykou', 'html_url': 'https://github.com/gerrykou', 'followers_url': 'https://api.github.com/users/gerrykou/followers', 'following_url': 'https://api.github.com/users/gerrykou/following{/other_user}', 'gists_url': 'https://api.github.com/users/gerrykou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gerrykou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gerrykou/subscriptions', 'organizations_url': 'https://api.github.com/users/gerrykou/orgs', 'repos_url': 'https://api.github.com/users/gerrykou/repos', 'events_url': 'https://api.github.com/users/gerrykou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gerrykou/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jdmonty', 'id': 3614077, 'node_id': 'MDQ6VXNlcjM2MTQwNzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3614077?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jdmonty', 'html_url': 'https://github.com/jdmonty', 'followers_url': 'https://api.github.com/users/jdmonty/followers', 'following_url': 'https://api.github.com/users/jdmonty/following{/other_user}', 'gists_url': 'https://api.github.com/users/jdmonty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jdmonty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jdmonty/subscriptions', 'organizations_url': 'https://api.github.com/users/jdmonty/orgs', 'repos_url': 'https://api.github.com/users/jdmonty/repos', 'events_url': 'https://api.github.com/users/jdmonty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jdmonty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login ...

# %% [markdown]
# So now we can rewrite our GitHub dlt pipeline using the RestAPI Client and `access_token`.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


# define new resource - github stargazers
@dlt.resource
def github_stargazers():
    client = RESTClient(
        base_url="https://api.github.com",
        auth=BearerTokenAuth(token=access_token)
    )

    for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
        yield page


# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_stargazers)
print(load_info)


# explore loaded data
pipeline.dataset(dataset_type="default").github_stargazers.df()
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 1.71 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1743232906.1323283 is LOADED and contains no failed jobs
#                          login         id               node_id  \
# 0                 lalitpagaria   19303690  MDQ6VXNlcjE5MzAzNjkw
# 1               nikitavoloboev    6391776  MDQ6VXNlcjYzOTE3NzY=
# 2                     gerrykou   13572514  MDQ6VXNlcjEzNTcyNTE0
# 3                      jdmonty    3614077  MDQ6VXNlcjM2MTQwNzc=
# 4               alexeygrigorev     875246  MDQ6VXNlcjg3NTI0Ng==
# ...                        ...        ...                   ...
# 6741  leonardo-fernandes-atria  154931574          U_kgDOCTwRdg
# 6742                   MHajjem   40360560  MDQ6VXNlcjQwMzYwNTYw
# 6743                  arstercz    1954680  MDQ6VXNlcjE5NTQ2ODA=
# 6744                benji-york       9391      MDQ6VXNlcjkzOTE=
# 6745                 elipinska   25990431  MDQ6VXNlcjI1OTkwNDMx
#
#                                              avatar_url gravatar_id  \
# 0     https://avatars.githubusercontent.com/u/193036...
# 1     https://avatars.githubusercontent.com/u/639177...
# 2     https://avatars.githubusercontent.com/u/135725...
# 3     https://avatars.githubusercontent.com/u/361407...
# 4     https://avatars.githubusercontent.com/u/875246...
# ...                                                 ...         ...
# 6741  https://avatars.githubusercontent.com/u/154931...
# 6742  https://avatars.githubusercontent.com/u/403605...
# 6743  https://avatars.githubusercontent.com/u/195468...
# 6744   https://avatars.githubusercontent.com/u/9391?v=4
# 6745  https://avatars.githubusercontent.com/u/259904...
#
#                                                     url  \
# 0             https://api.github.com/users/lalitpagaria
# 1           https://api.github.com/users/nikitavoloboev
# 2                 https://api.github.com/users/gerrykou
# 3                  https://api.github.com/users/jdmonty
# 4           https://api.github.com/users/alexeygrigorev
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742               https://api.github.com/users/MHajjem
# 6743              https://api.github.com/users/arstercz
# 6744            https://api.github.com/users/benji-york
# 6745             https://api.github.com/users/elipinska
#
#                                          html_url  \
# 0                 https://github.com/lalitpagaria
# 1               https://github.com/nikitavoloboev
# 2                     https://github.com/gerrykou
# 3                      https://github.com/jdmonty
# 4               https://github.com/alexeygrigorev
# ...                                           ...
# 6741  https://github.com/leonardo-fernandes-atria
# 6742                   https://github.com/MHajjem
# 6743                  https://github.com/arstercz
# 6744                https://github.com/benji-york
# 6745                 https://github.com/elipinska
#
#                                           followers_url  \
# 0     https://api.github.com/users/lalitpagaria/foll...
# 1     https://api.github.com/users/nikitavoloboev/fo...
# 2       https://api.github.com/users/gerrykou/followers
# 3        https://api.github.com/users/jdmonty/followers
# 4     https://api.github.com/users/alexeygrigorev/fo...
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742     https://api.github.com/users/MHajjem/followers
# 6743    https://api.github.com/users/arstercz/followers
# 6744  https://api.github.com/users/benji-york/followers
# 6745   https://api.github.com/users/elipinska/followers
#
#                                           following_url  \
# 0     https://api.github.com/users/lalitpagaria/foll...
# 1     https://api.github.com/users/nikitavoloboev/fo...
# 2     https://api.github.com/users/gerrykou/followin...
# 3     https://api.github.com/users/jdmonty/following...
# 4     https://api.github.com/users/alexeygrigorev/fo...
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742  https://api.github.com/users/MHajjem/following...
# 6743  https://api.github.com/users/arstercz/followin...
# 6744  https://api.github.com/users/benji-york/follow...
# 6745  https://api.github.com/users/elipinska/followi...
#
#                                               gists_url  ...  \
# 0     https://api.github.com/users/lalitpagaria/gist...  ...
# 1     https://api.github.com/users/nikitavoloboev/gi...  ...
# 2     https://api.github.com/users/gerrykou/gists{/g...  ...
# 3     https://api.github.com/users/jdmonty/gists{/gi...  ...
# 4     https://api.github.com/users/alexeygrigorev/gi...  ...
# ...                                                 ...  ...
# 6741  https://api.github.com/users/leonardo-fernande...  ...
# 6742  https://api.github.com/users/MHajjem/gists{/gi...  ...
# 6743  https://api.github.com/users/arstercz/gists{/g...  ...
# 6744  https://api.github.com/users/benji-york/gists{...  ...
# 6745  https://api.github.com/users/elipinska/gists{/...  ...
#
#                                       subscriptions_url  \
# 0     https://api.github.com/users/lalitpagaria/subs...
# 1     https://api.github.com/users/nikitavoloboev/su...
# 2     https://api.github.com/users/gerrykou/subscrip...
# 3     https://api.github.com/users/jdmonty/subscript...
# 4     https://api.github.com/users/alexeygrigorev/su...
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742  https://api.github.com/users/MHajjem/subscript...
# 6743  https://api.github.com/users/arstercz/subscrip...
# 6744  https://api.github.com/users/benji-york/subscr...
# 6745  https://api.github.com/users/elipinska/subscri...
#
#                                       organizations_url  \
# 0        https://api.github.com/users/lalitpagaria/orgs
# 1      https://api.github.com/users/nikitavoloboev/orgs
# 2            https://api.github.com/users/gerrykou/orgs
# 3             https://api.github.com/users/jdmonty/orgs
# 4      https://api.github.com/users/alexeygrigorev/orgs
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742          https://api.github.com/users/MHajjem/orgs
# 6743         https://api.github.com/users/arstercz/orgs
# 6744       https://api.github.com/users/benji-york/orgs
# 6745        https://api.github.com/users/elipinska/orgs
#
#                                               repos_url  \
# 0       https://api.github.com/users/lalitpagaria/repos
# 1     https://api.github.com/users/nikitavoloboev/repos
# 2           https://api.github.com/users/gerrykou/repos
# 3            https://api.github.com/users/jdmonty/repos
# 4     https://api.github.com/users/alexeygrigorev/repos
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742         https://api.github.com/users/MHajjem/repos
# 6743        https://api.github.com/users/arstercz/repos
# 6744      https://api.github.com/users/benji-york/repos
# 6745       https://api.github.com/users/elipinska/repos
#
#                                              events_url  \
# 0     https://api.github.com/users/lalitpagaria/even...
# 1     https://api.github.com/users/nikitavoloboev/ev...
# 2     https://api.github.com/users/gerrykou/events{/...
# 3     https://api.github.com/users/jdmonty/events{/p...
# 4     https://api.github.com/users/alexeygrigorev/ev...
# ...                                                 ...
# 6741  https://api.github.com/users/leonardo-fernande...
# 6742  https://api.github.com/users/MHajjem/events{/p...
# 6743  https://api.github.com/users/arstercz/events{/...
# 6744  https://api.github.com/users/benji-york/events...
# 6745  https://api.github.com/users/elipinska/events{...
#
#                                     received_events_url  type user_view_type  \
# 0     https://api.github.com/users/lalitpagaria/rece...  User         public
# 1     https://api.github.com/users/nikitavoloboev/re...  User         public
# 2     https://api.github.com/users/gerrykou/received...  User         public
# 3     https://api.github.com/users/jdmonty/received_...  User         public
# 4     https://api.github.com/users/alexeygrigorev/re...  User         public
# ...                                                 ...   ...            ...
# 6741  https://api.github.com/users/leonardo-fernande...  User         public
# 6742  https://api.github.com/users/MHajjem/received_...  User         public
# 6743  https://api.github.com/users/arstercz/received...  User         public
# 6744  https://api.github.com/users/benji-york/receiv...  User         public
# 6745  https://api.github.com/users/elipinska/receive...  User         public
#
#      site_admin        _dlt_load_id         _dlt_id
# 0         False  1743232719.6318479  vyaWY/qOYwxmaw
# 1         False  1743232719.6318479  NTxSi+2gw0Rfag
# 2         False  1743232719.6318479  8aRw1l6nRy2u/Q
# 3         False  1743232719.6318479  FcDqJ3toN3PMZQ
# 4         False  1743232719.6318479  r/6ApMpH6nJXZg
# ...         ...                 ...             ...
# 6741      False  1743232906.1323283  kcKuU3XC8YOsSQ
# 6742      False  1743232906.1323283  ph9tolX+qlSyzw
# 6743      False  1743232906.1323283  u8SDGXdxBSBLfg
# 6744      False  1743232906.1323283  OH0qFiOIHsx0cw
# 6745      False  1743232906.1323283  pOlGqBPBhBt3/g
#
# [6746 rows x 21 columns]

# %% [markdown]
# You can see that all dlt [stargazers](https://github.com/dlt-hub/dlt/stargazers) were loaded into the DuckDB destination.

# %% [markdown]
# ## **dlt configuration and secrets**
#
# In dlt, [configurations and secrets](https://dlthub.com/docs/general-usage/credentials/) are essential for setting up data pipelines.
#
# **Configurations** are **non-sensitive** settings that define the behavior of a data pipeline, including file paths, database hosts, timeouts, API URLs, and performance settings.
#
# On the other hand, **secrets** are **sensitive** data like passwords, API keys, and private keys, which should never be hard-coded to avoid security risks.
#
# These can be set up in various ways:
#
# * Environment variables
# * Within code using `dlt.secrets` and `dlt.config`
# * Configuration files (`secrets.toml` and `config.toml`)
#
# We're gonna use `dlt.secrets.value` to define credentials in resources and sources. dlt automatically **extracts** configuration settings and secrets based on flexible naming conventions. It then **injects** these values where needed in code.
#
# **Note**: It's important to note that while you can put all configurations and credentials in the `dlt.secrets` (or `secrets.toml`) if it's more convenient, credentials cannot be placed in `dlt.config` (or `config.toml`) because dlt doesn't look for them there.

# %% [markdown]
# Let's create dlt pipeline for both endpoints: `repos/dlt-hub/dlt/stargazers` and `orgs/dlt-hub/events`.
#
# We'll use `@dlt.source` to combine all resources in one place.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source():
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %% [markdown]
# Now we'll use `dlt.secrets.value` in our source to enable dlt secrets configuration. Rename `access_token` variable to `secret_key` because it's already defined.

# %%
exit()

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source(access_token=dlt.secrets.value): # <--- set the secret variable "access_token" here
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %% [markdown]
# Configs are defined in a similar way but are accessed using `dlt.config.value`. However, since configuration variables are internally managed by `dlt`, it is unlikely that you would need to explicitly use `dlt.config.value` in most cases.

# %% [markdown]
# If you run the pipeline with `secret_key` as `dlt.secrets.value`, you will see the following error:

# %%
# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in _get_source_item(self)
#     276
# --> 277                 pipe_item = next(gen)
#     278                 if pipe_item is not None:
#
# <ipython-input-12-0b3d3c17da59> in github_events()
#      15     def github_events():
# ---> 16         for page in client.paginate("orgs/dlt-hub/events"):
#      17             yield page
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, headers, **kwargs)
#     237             try:
# --> 238                 response = self._send_request(request, **kwargs)
#     239             except IgnoreResponseException:
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in _send_request(self, request, **kwargs)
#     143         send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 144         return self.session.send(prepared_request, **send_kwargs)
#     145
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/requests/session.py in send(self, request, **kwargs)
#      60         kwargs.setdefault("timeout", self.timeout)
# ---> 61         return super().send(request, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     709         # Response manipulation hooks
# --> 710         r = dispatch_hook("response", hooks, r, **kwargs)
#     711
#
# /usr/local/lib/python3.11/dist-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29         for hook in hooks:
# ---> 30             _hook_data = hook(hook_data, **kwargs)
#      31             if _hook_data is not None:
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in raise_for_status(response, *args, **kwargs)
#     328 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 329     response.raise_for_status()
#     330
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events
#
# The above exception was the direct cause of the following exception:
#
# ResourceExtractionError                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     465
# --> 466                     self._extract_source(
#     467                         extract_step,
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1237         # extract into pipeline schema
# -> 1238         load_id = extract.extract(
#    1239             source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/extract.py in extract(self, source, max_parallel_items, workers, load_package_state_update)
#     434
# --> 435                 self._extract_single_source(
#     436                     load_id,
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/extract.py in _extract_single_source(self, load_id, source, max_parallel_items, workers)
#     357                     collector.update("Resources", 0, total_gens)
# --> 358                     for pipe_item in pipes:
#     359                         curr_gens = len(pipes._sources)
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in __next__(self)
#     161                     # if none then take element from the newest source
# --> 162                     pipe_item = self._get_source_item()
#     163
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in _get_source_item(self)
#     306         except Exception as ex:
# --> 307             raise ResourceExtractionError(pipe.name, gen, str(ex), "generator") from ex
#     308
#
# ResourceExtractionError: In processing pipe github_events: extraction of resource github_events in generator github_events caused an exception: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# <ipython-input-13-a17599ba3010> in <cell line: 0>()
#       4
#       5 # run the pipeline with the new resource
# ----> 6 load_info = pipeline.run(github_source())
#       7 print(load_info)
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     219                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     220
# --> 221                 step_info = f(self, *args, **kwargs)
#     222                 return step_info
#     223             except Exception as ex:
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     268                 )
#     269             ):
# --> 270                 return f(self, *args, **kwargs)
#     271
#     272         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     728         # extract from the source
#     729         if data is not None:
# --> 730             self.extract(
#     731                 data,
#     732                 table_name=table_name,
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     219                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     220
# --> 221                 step_info = f(self, *args, **kwargs)
#     222                 return step_info
#     223             except Exception as ex:
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     173             self._schema_storage.commit_live_schema(name)
#     174         try:
# --> 175             rv = f(self, *args, **kwargs)
#     176         except Exception:
#     177             # because we committed live schema before calling f, we may safely
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     159             should_extract_state = may_extract_state and self.config.restore_from_destination
#     160             with self.managed_state(extract_state=should_extract_state):
# --> 161                 return f(self, *args, **kwargs)
#     162
#     163         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     268                 )
#     269             ):
# --> 270                 return f(self, *args, **kwargs)
#     271
#     272         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     485             step_info = self._get_step_info(extract_step)
#     486             current_load_id = step_info.loads_ids[-1] if len(step_info.loads_ids) > 0 else None
# --> 487             raise PipelineStepFailed(
#     488                 self,
#     489                 "extract",
#
# PipelineStepFailed: Pipeline execution failed at stage extract when processing package 1743232951.6620202 with exception:
#
# <class 'dlt.extract.exceptions.ResourceExtractionError'>
# In processing pipe github_events: extraction of resource github_events in generator github_events caused an exception: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events

# %% [markdown]
# ^ That is what happens if you set `dlt.secrets.value` for any variable in your dlt pipeline, but don't set the secret value up.
#
# dlt is looking for secrets in following formats:
#
# ```python
# ConfigFieldMissingException: Following fields are missing: ['access_token'] in configuration with spec GithubSourceConfiguration
# 	for field "access_token" config providers and keys were tried in following order:
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key ACCESS_TOKEN was not found.
# WARNING: dlt looks for .dlt folder in your current working directory and your cwd (/content) is different from directory of your pipeline script (/usr/local/lib/python3.10/dist-packages).
# If you keep your secret files in the same folder as your pipeline script but run your script from some other folder, secrets/configs will not be found
# Please refer to https://dlthub.com/docs/general-usage/credentials for more information
# ```

# %% [markdown]
# To define `access_token` secret value we can use:
#
# 1. `dlt.secrets` in code (recommended for secret vaults or dynamic creds)
# 2. Environment variables (recomnended for prod)
# 3. `secrets.toml` file (recommended for local dev)

# %% [markdown]
# ### **Use `dlt.secrets` in code**
#
# You can easily rewrite your secret right in the Python code. It's especially convenient if you take credentials from third-party secret providers, or if you want to update credentials and configs dinamically.

# %%
import os
from google.colab import userdata

dlt.secrets["access_token"] = userdata.get('github_api')

# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in _get_source_item(self)
#     276
# --> 277                 pipe_item = next(gen)
#     278                 if pipe_item is not None:
#
# <ipython-input-12-0b3d3c17da59> in github_events()
#      15     def github_events():
# ---> 16         for page in client.paginate("orgs/dlt-hub/events"):
#      17             yield page
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, headers, **kwargs)
#     237             try:
# --> 238                 response = self._send_request(request, **kwargs)
#     239             except IgnoreResponseException:
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in _send_request(self, request, **kwargs)
#     143         send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 144         return self.session.send(prepared_request, **send_kwargs)
#     145
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/requests/session.py in send(self, request, **kwargs)
#      60         kwargs.setdefault("timeout", self.timeout)
# ---> 61         return super().send(request, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     709         # Response manipulation hooks
# --> 710         r = dispatch_hook("response", hooks, r, **kwargs)
#     711
#
# /usr/local/lib/python3.11/dist-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29         for hook in hooks:
# ---> 30             _hook_data = hook(hook_data, **kwargs)
#      31             if _hook_data is not None:
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in raise_for_status(response, *args, **kwargs)
#     328 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 329     response.raise_for_status()
#     330
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events
#
# The above exception was the direct cause of the following exception:
#
# ResourceExtractionError                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     465
# --> 466                     self._extract_source(
#     467                         extract_step,
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1237         # extract into pipeline schema
# -> 1238         load_id = extract.extract(
#    1239             source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/extract.py in extract(self, source, max_parallel_items, workers, load_package_state_update)
#     434
# --> 435                 self._extract_single_source(
#     436                     load_id,
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/extract.py in _extract_single_source(self, load_id, source, max_parallel_items, workers)
#     357                     collector.update("Resources", 0, total_gens)
# --> 358                     for pipe_item in pipes:
#     359                         curr_gens = len(pipes._sources)
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in __next__(self)
#     161                     # if none then take element from the newest source
# --> 162                     pipe_item = self._get_source_item()
#     163
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in _get_source_item(self)
#     306         except Exception as ex:
# --> 307             raise ResourceExtractionError(pipe.name, gen, str(ex), "generator") from ex
#     308
#
# ResourceExtractionError: In processing pipe github_events: extraction of resource github_events in generator github_events caused an exception: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# <ipython-input-14-ce92ee7364f2> in <cell line: 0>()
#       9
#      10 # run the pipeline with the new resource
# ---> 11 load_info = pipeline.run(github_source())
#      12 print(load_info)
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     219                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     220
# --> 221                 step_info = f(self, *args, **kwargs)
#     222                 return step_info
#     223             except Exception as ex:
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     268                 )
#     269             ):
# --> 270                 return f(self, *args, **kwargs)
#     271
#     272         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     728         # extract from the source
#     729         if data is not None:
# --> 730             self.extract(
#     731                 data,
#     732                 table_name=table_name,
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     219                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     220
# --> 221                 step_info = f(self, *args, **kwargs)
#     222                 return step_info
#     223             except Exception as ex:
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     173             self._schema_storage.commit_live_schema(name)
#     174         try:
# --> 175             rv = f(self, *args, **kwargs)
#     176         except Exception:
#     177             # because we committed live schema before calling f, we may safely
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     159             should_extract_state = may_extract_state and self.config.restore_from_destination
#     160             with self.managed_state(extract_state=should_extract_state):
# --> 161                 return f(self, *args, **kwargs)
#     162
#     163         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     268                 )
#     269             ):
# --> 270                 return f(self, *args, **kwargs)
#     271
#     272         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     485             step_info = self._get_step_info(extract_step)
#     486             current_load_id = step_info.loads_ids[-1] if len(step_info.loads_ids) > 0 else None
# --> 487             raise PipelineStepFailed(
#     488                 self,
#     489                 "extract",
#
# PipelineStepFailed: Pipeline execution failed at stage extract when processing package 1743232964.827976 with exception:
#
# <class 'dlt.extract.exceptions.ResourceExtractionError'>
# In processing pipe github_events: extraction of resource github_events in generator github_events caused an exception: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events

# %% [markdown]
# Alternatively you can set:
#
# ```python
# dlt.secrets["sources.access_token"] = userdata.get('SECRET_KEY')
# dlt.secrets["sources.____main____.access_token"] = userdata.get('SECRET_KEY')
# dlt.secrets["sources.____main____.github_source.access_token"] = userdata.get('SECRET_KEY')
# ...
# ```

# %% [markdown]
# * `sources` is a special word;
#
# * `__main__` is a python module name;
#
# * `github_source` is the resource name;
#
# * `access_token` is the secret variable name.
#
#
# So dlt looks for secrets according to this hierarchy:
# ```
# pipeline_name
#     |
#     |-sources
#         |
#         |-<module name>
#             |
#             |-<source function 1 name>
#                 |
#                 |- secret variable 1
#                 |- secret variable 2
# ```
#
# To keep the **naming convention** flexible, dlt looks for a lot of **possible combinations** of key names, starting from the most specific possible path. Then, if the value is not found, it removes the right-most section and tries again.

# %% [markdown]
# ### **Exercise 2: Run pipeline with `dlt.secrets.value`**
#
# Explore the cells above and answer the question below using `sql_client`.
#
# #### Question
#
# Who has id=`17202864` in the `stargazers` table? Use `sql_client`.

# %%
with pipeline.sql_client() as client:
    with client.execute_query("SELECT DISTINCT login FROM github_stargazers WHERE id == 17202864") as cursor:
        data = cursor.df()
data
# Out:
#       login
# 0  rudolfix

# %% [markdown]
# ---
# ###  **Use environment variables**
#
# Let's set ENV in the one of the dlt formats: `ACCESS_TOKEN`.

# %%
import os
from google.colab import userdata

os.environ["ACCESS_TOKEN"] = userdata.get('github_api')

# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in _get_source_item(self)
#     276
# --> 277                 pipe_item = next(gen)
#     278                 if pipe_item is not None:
#
# <ipython-input-12-0b3d3c17da59> in github_events()
#      15     def github_events():
# ---> 16         for page in client.paginate("orgs/dlt-hub/events"):
#      17             yield page
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, headers, **kwargs)
#     237             try:
# --> 238                 response = self._send_request(request, **kwargs)
#     239             except IgnoreResponseException:
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in _send_request(self, request, **kwargs)
#     143         send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 144         return self.session.send(prepared_request, **send_kwargs)
#     145
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/requests/session.py in send(self, request, **kwargs)
#      60         kwargs.setdefault("timeout", self.timeout)
# ---> 61         return super().send(request, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     709         # Response manipulation hooks
# --> 710         r = dispatch_hook("response", hooks, r, **kwargs)
#     711
#
# /usr/local/lib/python3.11/dist-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29         for hook in hooks:
# ---> 30             _hook_data = hook(hook_data, **kwargs)
#      31             if _hook_data is not None:
#
# /usr/local/lib/python3.11/dist-packages/dlt/sources/helpers/rest_client/client.py in raise_for_status(response, *args, **kwargs)
#     328 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 329     response.raise_for_status()
#     330
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events
#
# The above exception was the direct cause of the following exception:
#
# ResourceExtractionError                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     465
# --> 466                     self._extract_source(
#     467                         extract_step,
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1237         # extract into pipeline schema
# -> 1238         load_id = extract.extract(
#    1239             source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/extract.py in extract(self, source, max_parallel_items, workers, load_package_state_update)
#     434
# --> 435                 self._extract_single_source(
#     436                     load_id,
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/extract.py in _extract_single_source(self, load_id, source, max_parallel_items, workers)
#     357                     collector.update("Resources", 0, total_gens)
# --> 358                     for pipe_item in pipes:
#     359                         curr_gens = len(pipes._sources)
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in __next__(self)
#     161                     # if none then take element from the newest source
# --> 162                     pipe_item = self._get_source_item()
#     163
#
# /usr/local/lib/python3.11/dist-packages/dlt/extract/pipe_iterator.py in _get_source_item(self)
#     306         except Exception as ex:
# --> 307             raise ResourceExtractionError(pipe.name, gen, str(ex), "generator") from ex
#     308
#
# ResourceExtractionError: In processing pipe github_events: extraction of resource github_events in generator github_events caused an exception: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# <ipython-input-16-2e57861dfa8f> in <cell line: 0>()
#       9
#      10 # run the pipeline with the new resource
# ---> 11 load_info = pipeline.run(github_source())
#      12 print(load_info)
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     219                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     220
# --> 221                 step_info = f(self, *args, **kwargs)
#     222                 return step_info
#     223             except Exception as ex:
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     268                 )
#     269             ):
# --> 270                 return f(self, *args, **kwargs)
#     271
#     272         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     728         # extract from the source
#     729         if data is not None:
# --> 730             self.extract(
#     731                 data,
#     732                 table_name=table_name,
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     219                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     220
# --> 221                 step_info = f(self, *args, **kwargs)
#     222                 return step_info
#     223             except Exception as ex:
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     173             self._schema_storage.commit_live_schema(name)
#     174         try:
# --> 175             rv = f(self, *args, **kwargs)
#     176         except Exception:
#     177             # because we committed live schema before calling f, we may safely
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     159             should_extract_state = may_extract_state and self.config.restore_from_destination
#     160             with self.managed_state(extract_state=should_extract_state):
# --> 161                 return f(self, *args, **kwargs)
#     162
#     163         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     268                 )
#     269             ):
# --> 270                 return f(self, *args, **kwargs)
#     271
#     272         return _wrap  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/dlt/pipeline/pipeline.py in extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     485             step_info = self._get_step_info(extract_step)
#     486             current_load_id = step_info.loads_ids[-1] if len(step_info.loads_ids) > 0 else None
# --> 487             raise PipelineStepFailed(
#     488                 self,
#     489                 "extract",
#
# PipelineStepFailed: Pipeline execution failed at stage extract when processing package 1743233043.5968838 with exception:
#
# <class 'dlt.extract.exceptions.ResourceExtractionError'>
# In processing pipe github_events: extraction of resource github_events in generator github_events caused an exception: 401 Client Error: Unauthorized for url: https://api.github.com/orgs/dlt-hub/events

# %% [markdown]
# Alternatively you can set:
#
# ```python
# os.environ["SOURCES__ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# os.environ["SOURCES____MAIN____ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# os.environ["SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# ...
# ```

# %% [markdown]
# **How does it work?**
#
# `dlt` **automatically extracts** configuration settings and secrets based on flexible naming conventions.
#
# It then **injects** these values where needed in functions decorated with `@dlt.source`, `@dlt.resource`, or `@dlt.destination`.
#
#
# >dlt uses a specific naming hierarchy to search for the secrets and config values. This makes configurations and secrets easy to manage.
# >
# > The naming convention for **environment variables** in dlt follows a specific pattern. All names are **capitalized** and sections are separated with **double underscores** __ , e.g.  `SOURCES____MAIN____GITHUB_SOURCE__SECRET_KEY`.

# %% [markdown]
# ---
# ###  **Use dlt `secrets.toml` or `config.toml`**

# %% [markdown]
# > Please note that Colab is not well-suited for using `secrets.toml` or `config.toml` files. As a result, these sections will provide instructions rather than code cells, detailing how to use them in a local environment. You should test this functionality on your own machine. For Colab, it is recommended to use environment variables instead.

# %% [markdown]
# The `secrets.toml` file - along with the `config.toml` file - should be stored in the `.dlt` directory where your pipeline code is located:
#
# ```
# /your_project_directory
# │
# ├── .dlt
# │   ├── secrets.toml
# │   └── config.toml
# │
# └── my_pipeline.py
# ```
#
# Read more about adding [credentials](https://dlthub.com/docs/walkthroughs/add_credentials) here.

# %% [markdown]
# To set credentials via TOMLs you would first add your access token to `secrets.toml`:
#
# ```toml
# # .dlt/secrets.toml
#
# [sources]
# secret_key = "your_access_token"
# ```

# %% [markdown]
# Alternatively you can set:
#
# ```
# [sources]
# secret_key = "your_access_token"
# ```
# is equal to:
#
# ```
# secret_key = "your_access_token"
# ```
#
# and to:
#
# ```
# [sources.____main____]
# secret_key = "your_access_token"
# ```
# and to:
#
# ```
# [sources.____main____.github_source]
# secret_key = "your_access_token"
# ```

# %% [markdown]
# ### **Configure Secrets in Colab**
#
# You can configure secrets using **Secrets** sidebar. Just create a variable with the name `secrets.toml` and paste the content of the toml file from your `.dlt` folder into it. We support `config.toml` variable as well.
#
# Open **Secrets** sidebar, press "Add new secret", create variable with name `secrets.toml` and copy-paste secrets in Value field and Enable it:
#
# ```
# [sources]
# secret_key = "your_access_token"
# ```
#
#
# >dlt will not reload the secrets automatically. **Please restart your interpreter** in Colab options when you add/change content of the variables above.

# %% [markdown]
# ![Screenshot 2024-11-29 at 14.38.01.png](data:image/png;base64,...)

# %% [markdown]
# ✅ ▶ Proceed to the [next lesson](https://colab.research.google.com/drive/1mfqZulsuFDc7h27d6joe2_Dduvl1uM-2?usp=sharing)!
